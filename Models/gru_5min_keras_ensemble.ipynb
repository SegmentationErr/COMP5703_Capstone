# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from keras import layers
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import numpy as np
import pandas as pd
import matplotlib
import tensorflow as tf
import sklearn

print('numpy==' + np.__version__)
print('pandas==' + pd.__version__)
print('matplotlib==' + matplotlib.__version__)
print('tensorflow-macos==' + tf.__version__)
print('sklearn==' + sklearn.__version__)
# Out:
# numpy==1.19.5
# pandas==1.3.2
# matplotlib==3.4.3
# tensorflow-macos==2.6.0
# sklearn==1.1.1

# %%
data_path = 'data/tweets_sentiment_score_price_5min_20210205_20220218.csv'
data = pd.read_csv(data_path).drop(['5min_TimeStart', 'time_period_end', 'time_open', 'time_close'], axis=1)

data.head()
# Out:
#    vander_pos  vander_neg  vander_neu  vander_compound  textblob_polarity  \
# 0    0.076889    0.022444    0.900667         0.165867           0.142593
# 1    0.134733    0.007533    0.857733         0.291440           0.147222
# 2    0.102364    0.000000    0.897636         0.290855           0.125455
# 3    0.096875    0.000000    0.903125         0.228200           0.116667
# 4    0.074571    0.042571    0.882857         0.135071           0.078571
#
#    textblob_subjectivity  price_open  price_high  price_low  price_close  \
# 0               0.319444    38320.00    38556.27   38230.81     38556.27
# 1               0.393519    38556.27    38653.07   38459.74     38493.23
# 2               0.634141    38479.01    38570.55   38426.39     38470.57
# 3               0.372173    38468.65    38468.65   38349.10     38378.40
# 4               0.435714    38391.75    38417.32   38312.39     38404.42
#
#    volume_traded  trades_count
# 0     138.679142           546
# 1      57.589145           338
# 2      16.038413           141
# 3       3.333530            77
# 4       8.892078           125

# %%
data_features = data.drop(['price_close'], axis=1)
data_labels = data['price_close']

# data = data.to_numpy()

scaler_feature = MinMaxScaler(feature_range=(0, 1))
scaler_label = MinMaxScaler(feature_range=(0, 1))

feature = scaler_feature.fit_transform(data_features.to_numpy())
label = scaler_label.fit_transform(data_labels.to_numpy().reshape(-1, 1))


train_size1 = int(0.7 * len(label))
train_size2 = int(0.9 * len(label))

# %%
print(data_features[:3])
print(data_labels[:3])
# Out:
#    vander_pos  vander_neg  vander_neu  vander_compound  textblob_polarity  \
# 0    0.076889    0.022444    0.900667         0.165867           0.142593
# 1    0.134733    0.007533    0.857733         0.291440           0.147222
# 2    0.102364    0.000000    0.897636         0.290855           0.125455
#
#    textblob_subjectivity  price_open  price_high  price_low  volume_traded  \
# 0               0.319444    38320.00    38556.27   38230.81     138.679142
# 1               0.393519    38556.27    38653.07   38459.74      57.589145
# 2               0.634141    38479.01    38570.55   38426.39      16.038413
#
#    trades_count
# 0           546
# 1           338
# 2           141
# 0    38556.27
# 1    38493.23
# 2    38470.57
# Name: price_close, dtype: float64

# %%
def split_data(f, l):
    delay = 15 * 12
    feature, label = [], []

    for i in range(len(f) - delay):
        feature.append(f[i: i + delay])
        label.append(l[i + delay-1])
        
    return np.array(feature), np.array(label).squeeze()

X_train, y_train = split_data(feature[:train_size1], label[:train_size1])
X_train2, y_train2 = split_data(feature[train_size1:train_size2], label[train_size1:train_size2])
X_test, y_test = split_data(feature[train_size2:], label[train_size2:])

# %%
models = [
    keras.Sequential([
        layers.GRU(128),
        layers.Dense(1)
    ]) for i in range(5)
]
# Out:
# 2022-09-07 08:41:47.020292: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:41:47.025869: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:41:47.026037: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:41:47.026909: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-07 08:41:47.027283: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:41:47.027438: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:41:47.027574: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:41:47.471552: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:41:47.471737: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:41:47.471877: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:41:47.472005: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4580 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
for i, model in enumerate(models):
    model.compile(loss='mean_squared_error',
                  optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.00005),
                  metrics=[keras.metrics.RootMeanSquaredError()]
                  )
    history = model.fit(X_train, y_train,
                        epochs=50,
                        batch_size=1024,
                        validation_data=(X_test, y_test),
                        callbacks=[keras.callbacks.ModelCheckpoint('gru-5min-'+str(i)+'.h5', verbose=1, monitor='val_root_mean_squared_error',save_best_only=True, mode='auto')],
                        shuffle=True
                        )
# Out:
# /home/charles/.local/lib/python3.8/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 2022-09-07 08:41:48.377267: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2022-09-07 08:41:49.964489: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8400
# 75/75 [==============================] - 5s 45ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 1.1969e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.00346, saving model to gru-5min-0.h5
# Epoch 2/50
# 75/75 [==============================] - 3s 40ms/step - loss: 2.1211e-05 - root_mean_squared_error: 0.0046 - val_loss: 7.8402e-06 - val_root_mean_squared_error: 0.0028
#
# Epoch 00002: val_root_mean_squared_error improved from 0.00346 to 0.00280, saving model to gru-5min-0.h5
# Epoch 3/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.5986e-05 - root_mean_squared_error: 0.0040 - val_loss: 6.7721e-06 - val_root_mean_squared_error: 0.0026
#
# Epoch 00003: val_root_mean_squared_error improved from 0.00280 to 0.00260, saving model to gru-5min-0.h5
# Epoch 4/50
# 75/75 [==============================] - 3s 40ms/step - loss: 1.4235e-05 - root_mean_squared_error: 0.0038 - val_loss: 6.1647e-06 - val_root_mean_squared_error: 0.0025
#
# Epoch 00004: val_root_mean_squared_error improved from 0.00260 to 0.00248, saving model to gru-5min-0.h5
# Epoch 5/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.2932e-05 - root_mean_squared_error: 0.0036 - val_loss: 5.6281e-06 - val_root_mean_squared_error: 0.0024
#
# Epoch 00005: val_root_mean_squared_error improved from 0.00248 to 0.00237, saving model to gru-5min-0.h5
# Epoch 6/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.1917e-05 - root_mean_squared_error: 0.0035 - val_loss: 5.2225e-06 - val_root_mean_squared_error: 0.0023
#
# Epoch 00006: val_root_mean_squared_error improved from 0.00237 to 0.00229, saving model to gru-5min-0.h5
# Epoch 7/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.1080e-05 - root_mean_squared_error: 0.0033 - val_loss: 5.2637e-06 - val_root_mean_squared_error: 0.0023
#
# Epoch 00007: val_root_mean_squared_error did not improve from 0.00229
# Epoch 8/50
# 75/75 [==============================] - 3s 40ms/step - loss: 1.0384e-05 - root_mean_squared_error: 0.0032 - val_loss: 4.8842e-06 - val_root_mean_squared_error: 0.0022
#
# Epoch 00008: val_root_mean_squared_error improved from 0.00229 to 0.00221, saving model to gru-5min-0.h5
# Epoch 9/50
# 75/75 [==============================] - 3s 41ms/step - loss: 9.7856e-06 - root_mean_squared_error: 0.0031 - val_loss: 4.6552e-06 - val_root_mean_squared_error: 0.0022
#
# Epoch 00009: val_root_mean_squared_error improved from 0.00221 to 0.00216, saving model to gru-5min-0.h5
# Epoch 10/50
# 75/75 [==============================] - 3s 41ms/step - loss: 9.3077e-06 - root_mean_squared_error: 0.0031 - val_loss: 4.2051e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00010: val_root_mean_squared_error improved from 0.00216 to 0.00205, saving model to gru-5min-0.h5
# Epoch 11/50
# 75/75 [==============================] - 3s 40ms/step - loss: 8.9014e-06 - root_mean_squared_error: 0.0030 - val_loss: 4.3473e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00011: val_root_mean_squared_error did not improve from 0.00205
# Epoch 12/50
# 75/75 [==============================] - 3s 40ms/step - loss: 8.4878e-06 - root_mean_squared_error: 0.0029 - val_loss: 4.2509e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00012: val_root_mean_squared_error did not improve from 0.00205
# Epoch 13/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.1591e-06 - root_mean_squared_error: 0.0029 - val_loss: 3.7927e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00013: val_root_mean_squared_error improved from 0.00205 to 0.00195, saving model to gru-5min-0.h5
# Epoch 14/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.8841e-06 - root_mean_squared_error: 0.0028 - val_loss: 3.5820e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00014: val_root_mean_squared_error improved from 0.00195 to 0.00189, saving model to gru-5min-0.h5
# Epoch 15/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.6601e-06 - root_mean_squared_error: 0.0028 - val_loss: 3.4578e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00015: val_root_mean_squared_error improved from 0.00189 to 0.00186, saving model to gru-5min-0.h5
# Epoch 16/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.4126e-06 - root_mean_squared_error: 0.0027 - val_loss: 3.3557e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00016: val_root_mean_squared_error improved from 0.00186 to 0.00183, saving model to gru-5min-0.h5
# Epoch 17/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.2412e-06 - root_mean_squared_error: 0.0027 - val_loss: 3.2754e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00017: val_root_mean_squared_error improved from 0.00183 to 0.00181, saving model to gru-5min-0.h5
# Epoch 18/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.0640e-06 - root_mean_squared_error: 0.0027 - val_loss: 3.3346e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00018: val_root_mean_squared_error did not improve from 0.00181
# Epoch 19/50
# 75/75 [==============================] - 3s 40ms/step - loss: 6.9878e-06 - root_mean_squared_error: 0.0026 - val_loss: 3.6133e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00019: val_root_mean_squared_error did not improve from 0.00181
# Epoch 20/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.7959e-06 - root_mean_squared_error: 0.0026 - val_loss: 3.1107e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00020: val_root_mean_squared_error improved from 0.00181 to 0.00176, saving model to gru-5min-0.h5
# Epoch 21/50
# 75/75 [==============================] - 3s 40ms/step - loss: 6.6419e-06 - root_mean_squared_error: 0.0026 - val_loss: 3.3437e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.00176
# Epoch 22/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.6954e-06 - root_mean_squared_error: 0.0026 - val_loss: 5.6598e-06 - val_root_mean_squared_error: 0.0024
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.00176
# Epoch 23/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.6277e-06 - root_mean_squared_error: 0.0026 - val_loss: 3.0116e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00023: val_root_mean_squared_error improved from 0.00176 to 0.00174, saving model to gru-5min-0.h5
# Epoch 24/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.2804e-06 - root_mean_squared_error: 0.0025 - val_loss: 4.3333e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.00174
# Epoch 25/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.2462e-06 - root_mean_squared_error: 0.0025 - val_loss: 2.8189e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00025: val_root_mean_squared_error improved from 0.00174 to 0.00168, saving model to gru-5min-0.h5
# Epoch 26/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.2103e-06 - root_mean_squared_error: 0.0025 - val_loss: 3.7620e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.00168
# Epoch 27/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.1796e-06 - root_mean_squared_error: 0.0025 - val_loss: 3.1867e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00027: val_root_mean_squared_error did not improve from 0.00168
# Epoch 28/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.0345e-06 - root_mean_squared_error: 0.0025 - val_loss: 2.8139e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00028: val_root_mean_squared_error improved from 0.00168 to 0.00168, saving model to gru-5min-0.h5
# Epoch 29/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.9874e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.8994e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.00168
# Epoch 30/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.9016e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.9718e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.00168
# Epoch 31/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.7648e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.0738e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.00168
# Epoch 32/50
# 75/75 [==============================] - 3s 40ms/step - loss: 5.8013e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.1316e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.00168
# Epoch 33/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.8928e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.1930e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.00168
# Epoch 34/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.6958e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.5174e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.00168
# Epoch 35/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.7288e-06 - root_mean_squared_error: 0.0024 - val_loss: 4.4458e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.00168
# Epoch 36/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.6346e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.7957e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00036: val_root_mean_squared_error improved from 0.00168 to 0.00167, saving model to gru-5min-0.h5
# Epoch 37/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.5532e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.4786e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00037: val_root_mean_squared_error improved from 0.00167 to 0.00157, saving model to gru-5min-0.h5
# Epoch 38/50
# 75/75 [==============================] - ETA: 0s - loss: 5.5472e-06 - root_mean_squared_error: 0.002 - 3s 41ms/step - loss: 5.5453e-06 - root_mean_squared_error: 0.0024 - val_loss: 5.2165e-06 - val_root_mean_squared_error: 0.0023
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.00157
# Epoch 39/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.9615e-06 - root_mean_squared_error: 0.0024 - val_loss: 4.5997e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.00157
# Epoch 40/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.7410e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.1211e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00040: val_root_mean_squared_error did not improve from 0.00157
# Epoch 41/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.5284e-06 - root_mean_squared_error: 0.0024 - val_loss: 6.4311e-06 - val_root_mean_squared_error: 0.0025
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.00157
# Epoch 42/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.0132e-06 - root_mean_squared_error: 0.0025 - val_loss: 2.9714e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.00157
# Epoch 43/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.5884e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.7151e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.00157
# Epoch 44/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.6517e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.6954e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.00157
# Epoch 45/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.6484e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.0679e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.00157
# Epoch 46/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.9246e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.7308e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.00157
# Epoch 47/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.0244e-06 - root_mean_squared_error: 0.0025 - val_loss: 5.5275e-06 - val_root_mean_squared_error: 0.0024
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.00157
# Epoch 48/50
# 75/75 [==============================] - 3s 41ms/step - loss: 9.2140e-06 - root_mean_squared_error: 0.0030 - val_loss: 5.0890e-06 - val_root_mean_squared_error: 0.0023
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.00157
# Epoch 49/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.6567e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.2438e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.00157
# Epoch 50/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.4141e-06 - root_mean_squared_error: 0.0025 - val_loss: 1.0199e-05 - val_root_mean_squared_error: 0.0032
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.00157
# Epoch 1/50
# 75/75 [==============================] - 4s 47ms/step - loss: 0.0078 - root_mean_squared_error: 0.0881 - val_loss: 1.9636e-05 - val_root_mean_squared_error: 0.0044
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.00443, saving model to gru-5min-1.h5
# Epoch 2/50
# 75/75 [==============================] - 3s 41ms/step - loss: 2.2795e-05 - root_mean_squared_error: 0.0048 - val_loss: 1.0221e-05 - val_root_mean_squared_error: 0.0032
#
# Epoch 00002: val_root_mean_squared_error improved from 0.00443 to 0.00320, saving model to gru-5min-1.h5
# Epoch 3/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.6214e-05 - root_mean_squared_error: 0.0040 - val_loss: 7.4831e-06 - val_root_mean_squared_error: 0.0027
#
# Epoch 00003: val_root_mean_squared_error improved from 0.00320 to 0.00274, saving model to gru-5min-1.h5
# Epoch 4/50
# 75/75 [==============================] - 3s 40ms/step - loss: 1.3933e-05 - root_mean_squared_error: 0.0037 - val_loss: 6.1983e-06 - val_root_mean_squared_error: 0.0025
#
# Epoch 00004: val_root_mean_squared_error improved from 0.00274 to 0.00249, saving model to gru-5min-1.h5
# Epoch 5/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.2506e-05 - root_mean_squared_error: 0.0035 - val_loss: 5.5425e-06 - val_root_mean_squared_error: 0.0024
#
# Epoch 00005: val_root_mean_squared_error improved from 0.00249 to 0.00235, saving model to gru-5min-1.h5
# Epoch 6/50
# 75/75 [==============================] - 3s 40ms/step - loss: 1.1417e-05 - root_mean_squared_error: 0.0034 - val_loss: 4.9604e-06 - val_root_mean_squared_error: 0.0022
#
# Epoch 00006: val_root_mean_squared_error improved from 0.00235 to 0.00223, saving model to gru-5min-1.h5
# Epoch 7/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.0605e-05 - root_mean_squared_error: 0.0033 - val_loss: 4.8335e-06 - val_root_mean_squared_error: 0.0022
#
# Epoch 00007: val_root_mean_squared_error improved from 0.00223 to 0.00220, saving model to gru-5min-1.h5
# Epoch 8/50
# 75/75 [==============================] - 3s 41ms/step - loss: 9.9261e-06 - root_mean_squared_error: 0.0032 - val_loss: 4.3697e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00008: val_root_mean_squared_error improved from 0.00220 to 0.00209, saving model to gru-5min-1.h5
# Epoch 9/50
# 75/75 [==============================] - 3s 41ms/step - loss: 9.3746e-06 - root_mean_squared_error: 0.0031 - val_loss: 4.1748e-06 - val_root_mean_squared_error: 0.0020
#
# Epoch 00009: val_root_mean_squared_error improved from 0.00209 to 0.00204, saving model to gru-5min-1.h5
# Epoch 10/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.9553e-06 - root_mean_squared_error: 0.0030 - val_loss: 4.1733e-06 - val_root_mean_squared_error: 0.0020
#
# Epoch 00010: val_root_mean_squared_error improved from 0.00204 to 0.00204, saving model to gru-5min-1.h5
# Epoch 11/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.5193e-06 - root_mean_squared_error: 0.0029 - val_loss: 3.8790e-06 - val_root_mean_squared_error: 0.0020
#
# Epoch 00011: val_root_mean_squared_error improved from 0.00204 to 0.00197, saving model to gru-5min-1.h5
# Epoch 12/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.2628e-06 - root_mean_squared_error: 0.0029 - val_loss: 3.7026e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00012: val_root_mean_squared_error improved from 0.00197 to 0.00192, saving model to gru-5min-1.h5
# Epoch 13/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.9465e-06 - root_mean_squared_error: 0.0028 - val_loss: 3.5570e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00013: val_root_mean_squared_error improved from 0.00192 to 0.00189, saving model to gru-5min-1.h5
# Epoch 14/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.6577e-06 - root_mean_squared_error: 0.0028 - val_loss: 4.4215e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00014: val_root_mean_squared_error did not improve from 0.00189
# Epoch 15/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.5008e-06 - root_mean_squared_error: 0.0027 - val_loss: 4.1238e-06 - val_root_mean_squared_error: 0.0020
#
# Epoch 00015: val_root_mean_squared_error did not improve from 0.00189
# Epoch 16/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.3858e-06 - root_mean_squared_error: 0.0027 - val_loss: 3.3310e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00016: val_root_mean_squared_error improved from 0.00189 to 0.00183, saving model to gru-5min-1.h5
# Epoch 17/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.0615e-06 - root_mean_squared_error: 0.0027 - val_loss: 3.2338e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00017: val_root_mean_squared_error improved from 0.00183 to 0.00180, saving model to gru-5min-1.h5
# Epoch 18/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.9095e-06 - root_mean_squared_error: 0.0026 - val_loss: 3.3263e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00018: val_root_mean_squared_error did not improve from 0.00180
# Epoch 19/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.7836e-06 - root_mean_squared_error: 0.0026 - val_loss: 5.0507e-06 - val_root_mean_squared_error: 0.0022
#
# Epoch 00019: val_root_mean_squared_error did not improve from 0.00180
# Epoch 20/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.7506e-06 - root_mean_squared_error: 0.0026 - val_loss: 2.9942e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00020: val_root_mean_squared_error improved from 0.00180 to 0.00173, saving model to gru-5min-1.h5
# Epoch 21/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.5301e-06 - root_mean_squared_error: 0.0026 - val_loss: 3.0636e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.00173
# Epoch 22/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.3983e-06 - root_mean_squared_error: 0.0025 - val_loss: 3.1911e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.00173
# Epoch 23/50
# 75/75 [==============================] - 3s 40ms/step - loss: 6.3650e-06 - root_mean_squared_error: 0.0025 - val_loss: 2.8967e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00023: val_root_mean_squared_error improved from 0.00173 to 0.00170, saving model to gru-5min-1.h5
# Epoch 24/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.2730e-06 - root_mean_squared_error: 0.0025 - val_loss: 3.0866e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.00170
# Epoch 25/50
# 75/75 [==============================] - 3s 40ms/step - loss: 6.1243e-06 - root_mean_squared_error: 0.0025 - val_loss: 5.3651e-06 - val_root_mean_squared_error: 0.0023
#
# Epoch 00025: val_root_mean_squared_error did not improve from 0.00170
# Epoch 26/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.2217e-06 - root_mean_squared_error: 0.0025 - val_loss: 2.6969e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00026: val_root_mean_squared_error improved from 0.00170 to 0.00164, saving model to gru-5min-1.h5
# Epoch 27/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.9238e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.6547e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00027: val_root_mean_squared_error improved from 0.00164 to 0.00163, saving model to gru-5min-1.h5
# Epoch 28/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.8523e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.8643e-06 - val_root_mean_squared_error: 0.0020
#
# Epoch 00028: val_root_mean_squared_error did not improve from 0.00163
# Epoch 29/50
# 75/75 [==============================] - 3s 40ms/step - loss: 5.9457e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.6592e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.00163
# Epoch 30/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.7734e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.6351e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.00163
# Epoch 31/50
# 75/75 [==============================] - 3s 40ms/step - loss: 5.9202e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.6431e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00031: val_root_mean_squared_error improved from 0.00163 to 0.00163, saving model to gru-5min-1.h5
# Epoch 32/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.5680e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.9334e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.00163
# Epoch 33/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.5779e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.6366e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00033: val_root_mean_squared_error improved from 0.00163 to 0.00162, saving model to gru-5min-1.h5
# Epoch 34/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.4676e-06 - root_mean_squared_error: 0.0023 - val_loss: 2.6586e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.00162
# Epoch 35/50
# 75/75 [==============================] - 3s 40ms/step - loss: 5.5037e-06 - root_mean_squared_error: 0.0023 - val_loss: 2.6936e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.00162
# Epoch 36/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.5330e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.4355e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00036: val_root_mean_squared_error improved from 0.00162 to 0.00156, saving model to gru-5min-1.h5
# Epoch 37/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.5637e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.4211e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00037: val_root_mean_squared_error improved from 0.00156 to 0.00156, saving model to gru-5min-1.h5
# Epoch 38/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.2627e-06 - root_mean_squared_error: 0.0023 - val_loss: 3.3697e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.00156
# Epoch 39/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.3326e-06 - root_mean_squared_error: 0.0023 - val_loss: 4.4763e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.00156
# Epoch 40/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.5721e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.3584e-06 - val_root_mean_squared_error: 0.0015
#
# Epoch 00040: val_root_mean_squared_error improved from 0.00156 to 0.00154, saving model to gru-5min-1.h5
# Epoch 41/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.2561e-06 - root_mean_squared_error: 0.0023 - val_loss: 2.3100e-06 - val_root_mean_squared_error: 0.0015
#
# Epoch 00041: val_root_mean_squared_error improved from 0.00154 to 0.00152, saving model to gru-5min-1.h5
# Epoch 42/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.2487e-06 - root_mean_squared_error: 0.0023 - val_loss: 2.6652e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.00152
# Epoch 43/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.2212e-06 - root_mean_squared_error: 0.0023 - val_loss: 5.5157e-06 - val_root_mean_squared_error: 0.0023
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.00152
# Epoch 44/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.9196e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.4515e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.00152
# Epoch 45/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.8232e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.1973e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.00152
# Epoch 46/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.2232e-06 - root_mean_squared_error: 0.0025 - val_loss: 7.8649e-06 - val_root_mean_squared_error: 0.0028
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.00152
# Epoch 47/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.9584e-06 - root_mean_squared_error: 0.0024 - val_loss: 1.1744e-05 - val_root_mean_squared_error: 0.0034
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.00152
# Epoch 48/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.2372e-06 - root_mean_squared_error: 0.0027 - val_loss: 2.9415e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.00152
# Epoch 49/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.0257e-05 - root_mean_squared_error: 0.0032 - val_loss: 2.3407e-06 - val_root_mean_squared_error: 0.0015
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.00152
# Epoch 50/50
# 75/75 [==============================] - 3s 40ms/step - loss: 8.1641e-06 - root_mean_squared_error: 0.0029 - val_loss: 1.2685e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.00152
# Epoch 1/50
# 75/75 [==============================] - 4s 45ms/step - loss: 0.0278 - root_mean_squared_error: 0.1668 - val_loss: 6.4634e-05 - val_root_mean_squared_error: 0.0080
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.00804, saving model to gru-5min-2.h5
# Epoch 2/50
# 75/75 [==============================] - 3s 41ms/step - loss: 2.8857e-05 - root_mean_squared_error: 0.0054 - val_loss: 1.1041e-05 - val_root_mean_squared_error: 0.0033
#
# Epoch 00002: val_root_mean_squared_error improved from 0.00804 to 0.00332, saving model to gru-5min-2.h5
# Epoch 3/50
# 75/75 [==============================] - 3s 41ms/step - loss: 2.0504e-05 - root_mean_squared_error: 0.0045 - val_loss: 1.0082e-05 - val_root_mean_squared_error: 0.0032
#
# Epoch 00003: val_root_mean_squared_error improved from 0.00332 to 0.00318, saving model to gru-5min-2.h5
# Epoch 4/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.8210e-05 - root_mean_squared_error: 0.0043 - val_loss: 9.2252e-06 - val_root_mean_squared_error: 0.0030
#
# Epoch 00004: val_root_mean_squared_error improved from 0.00318 to 0.00304, saving model to gru-5min-2.h5
# Epoch 5/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.6258e-05 - root_mean_squared_error: 0.0040 - val_loss: 8.2481e-06 - val_root_mean_squared_error: 0.0029
#
# Epoch 00005: val_root_mean_squared_error improved from 0.00304 to 0.00287, saving model to gru-5min-2.h5
# Epoch 6/50
# 75/75 [==============================] - 3s 40ms/step - loss: 1.4611e-05 - root_mean_squared_error: 0.0038 - val_loss: 7.5661e-06 - val_root_mean_squared_error: 0.0028
#
# Epoch 00006: val_root_mean_squared_error improved from 0.00287 to 0.00275, saving model to gru-5min-2.h5
# Epoch 7/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.3197e-05 - root_mean_squared_error: 0.0036 - val_loss: 6.8782e-06 - val_root_mean_squared_error: 0.0026
#
# Epoch 00007: val_root_mean_squared_error improved from 0.00275 to 0.00262, saving model to gru-5min-2.h5
# Epoch 8/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.2036e-05 - root_mean_squared_error: 0.0035 - val_loss: 6.3144e-06 - val_root_mean_squared_error: 0.0025
#
# Epoch 00008: val_root_mean_squared_error improved from 0.00262 to 0.00251, saving model to gru-5min-2.h5
# Epoch 9/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.1125e-05 - root_mean_squared_error: 0.0033 - val_loss: 5.5328e-06 - val_root_mean_squared_error: 0.0024
#
# Epoch 00009: val_root_mean_squared_error improved from 0.00251 to 0.00235, saving model to gru-5min-2.h5
# Epoch 10/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.0219e-05 - root_mean_squared_error: 0.0032 - val_loss: 5.0183e-06 - val_root_mean_squared_error: 0.0022
#
# Epoch 00010: val_root_mean_squared_error improved from 0.00235 to 0.00224, saving model to gru-5min-2.h5
# Epoch 11/50
# 75/75 [==============================] - 3s 41ms/step - loss: 9.5456e-06 - root_mean_squared_error: 0.0031 - val_loss: 4.6413e-06 - val_root_mean_squared_error: 0.0022
#
# Epoch 00011: val_root_mean_squared_error improved from 0.00224 to 0.00215, saving model to gru-5min-2.h5
# Epoch 12/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.9929e-06 - root_mean_squared_error: 0.0030 - val_loss: 4.3380e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00012: val_root_mean_squared_error improved from 0.00215 to 0.00208, saving model to gru-5min-2.h5
# Epoch 13/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.5425e-06 - root_mean_squared_error: 0.0029 - val_loss: 4.0843e-06 - val_root_mean_squared_error: 0.0020
#
# Epoch 00013: val_root_mean_squared_error improved from 0.00208 to 0.00202, saving model to gru-5min-2.h5
# Epoch 14/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.1803e-06 - root_mean_squared_error: 0.0029 - val_loss: 3.9005e-06 - val_root_mean_squared_error: 0.0020
#
# Epoch 00014: val_root_mean_squared_error improved from 0.00202 to 0.00197, saving model to gru-5min-2.h5
# Epoch 15/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.8532e-06 - root_mean_squared_error: 0.0028 - val_loss: 3.7253e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00015: val_root_mean_squared_error improved from 0.00197 to 0.00193, saving model to gru-5min-2.h5
# Epoch 16/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.5823e-06 - root_mean_squared_error: 0.0028 - val_loss: 3.5508e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00016: val_root_mean_squared_error improved from 0.00193 to 0.00188, saving model to gru-5min-2.h5
# Epoch 17/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.3679e-06 - root_mean_squared_error: 0.0027 - val_loss: 3.5802e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00017: val_root_mean_squared_error did not improve from 0.00188
# Epoch 18/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.1867e-06 - root_mean_squared_error: 0.0027 - val_loss: 3.3714e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00018: val_root_mean_squared_error improved from 0.00188 to 0.00184, saving model to gru-5min-2.h5
# Epoch 19/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.9497e-06 - root_mean_squared_error: 0.0026 - val_loss: 3.2565e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00019: val_root_mean_squared_error improved from 0.00184 to 0.00180, saving model to gru-5min-2.h5
# Epoch 20/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.8002e-06 - root_mean_squared_error: 0.0026 - val_loss: 3.1795e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00020: val_root_mean_squared_error improved from 0.00180 to 0.00178, saving model to gru-5min-2.h5
# Epoch 21/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.6640e-06 - root_mean_squared_error: 0.0026 - val_loss: 3.2370e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.00178
# Epoch 22/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.5498e-06 - root_mean_squared_error: 0.0026 - val_loss: 3.8251e-06 - val_root_mean_squared_error: 0.0020
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.00178
# Epoch 23/50
# 75/75 [==============================] - 3s 40ms/step - loss: 6.4876e-06 - root_mean_squared_error: 0.0025 - val_loss: 2.9726e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00023: val_root_mean_squared_error improved from 0.00178 to 0.00172, saving model to gru-5min-2.h5
# Epoch 24/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.2999e-06 - root_mean_squared_error: 0.0025 - val_loss: 2.9852e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.00172
# Epoch 25/50
# 75/75 [==============================] - 3s 40ms/step - loss: 6.1750e-06 - root_mean_squared_error: 0.0025 - val_loss: 2.8679e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00025: val_root_mean_squared_error improved from 0.00172 to 0.00169, saving model to gru-5min-2.h5
# Epoch 26/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.0812e-06 - root_mean_squared_error: 0.0025 - val_loss: 2.8226e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00026: val_root_mean_squared_error improved from 0.00169 to 0.00168, saving model to gru-5min-2.h5
# Epoch 27/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.0066e-06 - root_mean_squared_error: 0.0025 - val_loss: 3.1243e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00027: val_root_mean_squared_error did not improve from 0.00168
# Epoch 28/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.9110e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.8160e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00028: val_root_mean_squared_error improved from 0.00168 to 0.00168, saving model to gru-5min-2.h5
# Epoch 29/50
# 75/75 [==============================] - 3s 40ms/step - loss: 5.8273e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.7266e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00029: val_root_mean_squared_error improved from 0.00168 to 0.00165, saving model to gru-5min-2.h5
# Epoch 30/50
# 75/75 [==============================] - 3s 40ms/step - loss: 5.7368e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.7151e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00030: val_root_mean_squared_error improved from 0.00165 to 0.00165, saving model to gru-5min-2.h5
# Epoch 31/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.6584e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.9359e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.00165
# Epoch 32/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.6243e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.7533e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.00165
# Epoch 33/50
# 75/75 [==============================] - 3s 40ms/step - loss: 5.5560e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.5527e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00033: val_root_mean_squared_error improved from 0.00165 to 0.00160, saving model to gru-5min-2.h5
# Epoch 34/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.4641e-06 - root_mean_squared_error: 0.0023 - val_loss: 2.8537e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.00160
# Epoch 35/50
# 75/75 [==============================] - 3s 40ms/step - loss: 5.4441e-06 - root_mean_squared_error: 0.0023 - val_loss: 3.2865e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.00160
# Epoch 36/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.4400e-06 - root_mean_squared_error: 0.0023 - val_loss: 2.7696e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.00160
# Epoch 37/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.2682e-06 - root_mean_squared_error: 0.0023 - val_loss: 2.4496e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00037: val_root_mean_squared_error improved from 0.00160 to 0.00157, saving model to gru-5min-2.h5
# Epoch 38/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.2076e-06 - root_mean_squared_error: 0.0023 - val_loss: 3.0974e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.00157
# Epoch 39/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.1731e-06 - root_mean_squared_error: 0.0023 - val_loss: 2.5160e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.00157
# Epoch 40/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.1400e-06 - root_mean_squared_error: 0.0023 - val_loss: 2.5137e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00040: val_root_mean_squared_error did not improve from 0.00157
# Epoch 41/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.0648e-06 - root_mean_squared_error: 0.0023 - val_loss: 2.3396e-06 - val_root_mean_squared_error: 0.0015
#
# Epoch 00041: val_root_mean_squared_error improved from 0.00157 to 0.00153, saving model to gru-5min-2.h5
# Epoch 42/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.0457e-06 - root_mean_squared_error: 0.0022 - val_loss: 2.3821e-06 - val_root_mean_squared_error: 0.0015
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.00153
# Epoch 43/50
# 75/75 [==============================] - 3s 41ms/step - loss: 4.9256e-06 - root_mean_squared_error: 0.0022 - val_loss: 2.3361e-06 - val_root_mean_squared_error: 0.0015
#
# Epoch 00043: val_root_mean_squared_error improved from 0.00153 to 0.00153, saving model to gru-5min-2.h5
# Epoch 44/50
# 75/75 [==============================] - 3s 41ms/step - loss: 4.9472e-06 - root_mean_squared_error: 0.0022 - val_loss: 2.8357e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.00153
# Epoch 45/50
# 75/75 [==============================] - 3s 41ms/step - loss: 4.9363e-06 - root_mean_squared_error: 0.0022 - val_loss: 2.2559e-06 - val_root_mean_squared_error: 0.0015
#
# Epoch 00045: val_root_mean_squared_error improved from 0.00153 to 0.00150, saving model to gru-5min-2.h5
# Epoch 46/50
# 75/75 [==============================] - 3s 41ms/step - loss: 4.7820e-06 - root_mean_squared_error: 0.0022 - val_loss: 2.2251e-06 - val_root_mean_squared_error: 0.0015
#
# Epoch 00046: val_root_mean_squared_error improved from 0.00150 to 0.00149, saving model to gru-5min-2.h5
# Epoch 47/50
# 75/75 [==============================] - 3s 41ms/step - loss: 4.7957e-06 - root_mean_squared_error: 0.0022 - val_loss: 2.5608e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.00149
# Epoch 48/50
# 75/75 [==============================] - 3s 41ms/step - loss: 4.8364e-06 - root_mean_squared_error: 0.0022 - val_loss: 2.5980e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.00149
# Epoch 49/50
# 75/75 [==============================] - 3s 41ms/step - loss: 4.7068e-06 - root_mean_squared_error: 0.0022 - val_loss: 2.7536e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.00149
# Epoch 50/50
# 75/75 [==============================] - 3s 40ms/step - loss: 4.7159e-06 - root_mean_squared_error: 0.0022 - val_loss: 2.1600e-06 - val_root_mean_squared_error: 0.0015
#
# Epoch 00050: val_root_mean_squared_error improved from 0.00149 to 0.00147, saving model to gru-5min-2.h5
# Epoch 1/50
# 75/75 [==============================] - 4s 45ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 2.5884e-05 - val_root_mean_squared_error: 0.0051
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.00509, saving model to gru-5min-3.h5
# Epoch 2/50
# 75/75 [==============================] - 3s 41ms/step - loss: 4.8082e-05 - root_mean_squared_error: 0.0069 - val_loss: 1.7869e-05 - val_root_mean_squared_error: 0.0042
#
# Epoch 00002: val_root_mean_squared_error improved from 0.00509 to 0.00423, saving model to gru-5min-3.h5
# Epoch 3/50
# 75/75 [==============================] - 3s 41ms/step - loss: 3.6251e-05 - root_mean_squared_error: 0.0060 - val_loss: 1.6250e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00003: val_root_mean_squared_error improved from 0.00423 to 0.00403, saving model to gru-5min-3.h5
# Epoch 4/50
# 75/75 [==============================] - 3s 41ms/step - loss: 2.9752e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.4189e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00004: val_root_mean_squared_error improved from 0.00403 to 0.00377, saving model to gru-5min-3.h5
# Epoch 5/50
# 75/75 [==============================] - 3s 41ms/step - loss: 2.5107e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.2667e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00005: val_root_mean_squared_error improved from 0.00377 to 0.00356, saving model to gru-5min-3.h5
# Epoch 6/50
# 75/75 [==============================] - 3s 40ms/step - loss: 2.1593e-05 - root_mean_squared_error: 0.0046 - val_loss: 1.0948e-05 - val_root_mean_squared_error: 0.0033
#
# Epoch 00006: val_root_mean_squared_error improved from 0.00356 to 0.00331, saving model to gru-5min-3.h5
# Epoch 7/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.8999e-05 - root_mean_squared_error: 0.0044 - val_loss: 9.3872e-06 - val_root_mean_squared_error: 0.0031
#
# Epoch 00007: val_root_mean_squared_error improved from 0.00331 to 0.00306, saving model to gru-5min-3.h5
# Epoch 8/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.7055e-05 - root_mean_squared_error: 0.0041 - val_loss: 8.1544e-06 - val_root_mean_squared_error: 0.0029
#
# Epoch 00008: val_root_mean_squared_error improved from 0.00306 to 0.00286, saving model to gru-5min-3.h5
# Epoch 9/50
# 75/75 [==============================] - 3s 40ms/step - loss: 1.5516e-05 - root_mean_squared_error: 0.0039 - val_loss: 7.3449e-06 - val_root_mean_squared_error: 0.0027
#
# Epoch 00009: val_root_mean_squared_error improved from 0.00286 to 0.00271, saving model to gru-5min-3.h5
# Epoch 10/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.4300e-05 - root_mean_squared_error: 0.0038 - val_loss: 7.8233e-06 - val_root_mean_squared_error: 0.0028
#
# Epoch 00010: val_root_mean_squared_error did not improve from 0.00271
# Epoch 11/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.3453e-05 - root_mean_squared_error: 0.0037 - val_loss: 6.3773e-06 - val_root_mean_squared_error: 0.0025
#
# Epoch 00011: val_root_mean_squared_error improved from 0.00271 to 0.00253, saving model to gru-5min-3.h5
# Epoch 12/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.2454e-05 - root_mean_squared_error: 0.0035 - val_loss: 6.4211e-06 - val_root_mean_squared_error: 0.0025
#
# Epoch 00012: val_root_mean_squared_error did not improve from 0.00253
# Epoch 13/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.1802e-05 - root_mean_squared_error: 0.0034 - val_loss: 5.7404e-06 - val_root_mean_squared_error: 0.0024
#
# Epoch 00013: val_root_mean_squared_error improved from 0.00253 to 0.00240, saving model to gru-5min-3.h5
# Epoch 14/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.1054e-05 - root_mean_squared_error: 0.0033 - val_loss: 5.3976e-06 - val_root_mean_squared_error: 0.0023
#
# Epoch 00014: val_root_mean_squared_error improved from 0.00240 to 0.00232, saving model to gru-5min-3.h5
# Epoch 15/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.0540e-05 - root_mean_squared_error: 0.0032 - val_loss: 5.0402e-06 - val_root_mean_squared_error: 0.0022
#
# Epoch 00015: val_root_mean_squared_error improved from 0.00232 to 0.00225, saving model to gru-5min-3.h5
# Epoch 16/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.0063e-05 - root_mean_squared_error: 0.0032 - val_loss: 4.7574e-06 - val_root_mean_squared_error: 0.0022
#
# Epoch 00016: val_root_mean_squared_error improved from 0.00225 to 0.00218, saving model to gru-5min-3.h5
# Epoch 17/50
# 75/75 [==============================] - 3s 41ms/step - loss: 9.6927e-06 - root_mean_squared_error: 0.0031 - val_loss: 4.5588e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00017: val_root_mean_squared_error improved from 0.00218 to 0.00214, saving model to gru-5min-3.h5
# Epoch 18/50
# 75/75 [==============================] - 3s 41ms/step - loss: 9.3441e-06 - root_mean_squared_error: 0.0031 - val_loss: 4.4591e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00018: val_root_mean_squared_error improved from 0.00214 to 0.00211, saving model to gru-5min-3.h5
# Epoch 19/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.9916e-06 - root_mean_squared_error: 0.0030 - val_loss: 4.2318e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00019: val_root_mean_squared_error improved from 0.00211 to 0.00206, saving model to gru-5min-3.h5
# Epoch 20/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.6557e-06 - root_mean_squared_error: 0.0029 - val_loss: 4.2623e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00020: val_root_mean_squared_error did not improve from 0.00206
# Epoch 21/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.4312e-06 - root_mean_squared_error: 0.0029 - val_loss: 3.9912e-06 - val_root_mean_squared_error: 0.0020
#
# Epoch 00021: val_root_mean_squared_error improved from 0.00206 to 0.00200, saving model to gru-5min-3.h5
# Epoch 22/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.1442e-06 - root_mean_squared_error: 0.0029 - val_loss: 3.8099e-06 - val_root_mean_squared_error: 0.0020
#
# Epoch 00022: val_root_mean_squared_error improved from 0.00200 to 0.00195, saving model to gru-5min-3.h5
# Epoch 23/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.8669e-06 - root_mean_squared_error: 0.0028 - val_loss: 3.8841e-06 - val_root_mean_squared_error: 0.0020
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.00195
# Epoch 24/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.6991e-06 - root_mean_squared_error: 0.0028 - val_loss: 3.5783e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00024: val_root_mean_squared_error improved from 0.00195 to 0.00189, saving model to gru-5min-3.h5
# Epoch 25/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.4935e-06 - root_mean_squared_error: 0.0027 - val_loss: 4.6040e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00025: val_root_mean_squared_error did not improve from 0.00189
# Epoch 26/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.5418e-06 - root_mean_squared_error: 0.0027 - val_loss: 5.0370e-06 - val_root_mean_squared_error: 0.0022
#
# ...
#
# Epoch 00040: val_root_mean_squared_error improved from 0.00166 to 0.00164, saving model to gru-5min-3.h5
# Epoch 41/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.7710e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.0710e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.00164
# Epoch 42/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.7633e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.7007e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.00164
# Epoch 43/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.6726e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.4796e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.00164
# Epoch 44/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.7051e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.3808e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.00164
# Epoch 45/50
# 75/75 [==============================] - 3s 40ms/step - loss: 5.7243e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.5547e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00045: val_root_mean_squared_error improved from 0.00164 to 0.00160, saving model to gru-5min-3.h5
# Epoch 46/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.5845e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.5973e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.00160
# Epoch 47/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.4930e-06 - root_mean_squared_error: 0.0023 - val_loss: 3.1258e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.00160
# Epoch 48/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.6558e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.7645e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.00160
# Epoch 49/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.3954e-06 - root_mean_squared_error: 0.0023 - val_loss: 4.0739e-06 - val_root_mean_squared_error: 0.0020
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.00160
# Epoch 50/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.5357e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.5842e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.00160
# Epoch 1/50
# 75/75 [==============================] - 4s 46ms/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 3.1016e-05 - val_root_mean_squared_error: 0.0056
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.00557, saving model to gru-5min-4.h5
# Epoch 2/50
# 75/75 [==============================] - 3s 41ms/step - loss: 3.1256e-05 - root_mean_squared_error: 0.0056 - val_loss: 1.7132e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00002: val_root_mean_squared_error improved from 0.00557 to 0.00414, saving model to gru-5min-4.h5
# Epoch 3/50
# 75/75 [==============================] - 3s 41ms/step - loss: 2.3204e-05 - root_mean_squared_error: 0.0048 - val_loss: 1.5213e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00003: val_root_mean_squared_error improved from 0.00414 to 0.00390, saving model to gru-5min-4.h5
# Epoch 4/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.9170e-05 - root_mean_squared_error: 0.0044 - val_loss: 1.1589e-05 - val_root_mean_squared_error: 0.0034
#
# Epoch 00004: val_root_mean_squared_error improved from 0.00390 to 0.00340, saving model to gru-5min-4.h5
# Epoch 5/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.6305e-05 - root_mean_squared_error: 0.0040 - val_loss: 9.5687e-06 - val_root_mean_squared_error: 0.0031
#
# Epoch 00005: val_root_mean_squared_error improved from 0.00340 to 0.00309, saving model to gru-5min-4.h5
# Epoch 6/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.4377e-05 - root_mean_squared_error: 0.0038 - val_loss: 8.3778e-06 - val_root_mean_squared_error: 0.0029
#
# Epoch 00006: val_root_mean_squared_error improved from 0.00309 to 0.00289, saving model to gru-5min-4.h5
# Epoch 7/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.2868e-05 - root_mean_squared_error: 0.0036 - val_loss: 8.0385e-06 - val_root_mean_squared_error: 0.0028
#
# Epoch 00007: val_root_mean_squared_error improved from 0.00289 to 0.00284, saving model to gru-5min-4.h5
# Epoch 8/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.1711e-05 - root_mean_squared_error: 0.0034 - val_loss: 8.6300e-06 - val_root_mean_squared_error: 0.0029
#
# Epoch 00008: val_root_mean_squared_error did not improve from 0.00284
# Epoch 9/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.0967e-05 - root_mean_squared_error: 0.0033 - val_loss: 6.2515e-06 - val_root_mean_squared_error: 0.0025
#
# Epoch 00009: val_root_mean_squared_error improved from 0.00284 to 0.00250, saving model to gru-5min-4.h5
# Epoch 10/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.0292e-05 - root_mean_squared_error: 0.0032 - val_loss: 5.7231e-06 - val_root_mean_squared_error: 0.0024
#
# Epoch 00010: val_root_mean_squared_error improved from 0.00250 to 0.00239, saving model to gru-5min-4.h5
# Epoch 11/50
# 75/75 [==============================] - 3s 41ms/step - loss: 9.5412e-06 - root_mean_squared_error: 0.0031 - val_loss: 5.0779e-06 - val_root_mean_squared_error: 0.0023
#
# Epoch 00011: val_root_mean_squared_error improved from 0.00239 to 0.00225, saving model to gru-5min-4.h5
# Epoch 12/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.9283e-06 - root_mean_squared_error: 0.0030 - val_loss: 5.1429e-06 - val_root_mean_squared_error: 0.0023
#
# Epoch 00012: val_root_mean_squared_error did not improve from 0.00225
# Epoch 13/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.4863e-06 - root_mean_squared_error: 0.0029 - val_loss: 4.9036e-06 - val_root_mean_squared_error: 0.0022
#
# Epoch 00013: val_root_mean_squared_error improved from 0.00225 to 0.00221, saving model to gru-5min-4.h5
# Epoch 14/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.1474e-06 - root_mean_squared_error: 0.0029 - val_loss: 4.1420e-06 - val_root_mean_squared_error: 0.0020
#
# Epoch 00014: val_root_mean_squared_error improved from 0.00221 to 0.00204, saving model to gru-5min-4.h5
# Epoch 15/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.7089e-06 - root_mean_squared_error: 0.0028 - val_loss: 4.2226e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00015: val_root_mean_squared_error did not improve from 0.00204
# Epoch 16/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.4222e-06 - root_mean_squared_error: 0.0027 - val_loss: 3.6941e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00016: val_root_mean_squared_error improved from 0.00204 to 0.00192, saving model to gru-5min-4.h5
# Epoch 17/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.1241e-06 - root_mean_squared_error: 0.0027 - val_loss: 3.6218e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00017: val_root_mean_squared_error improved from 0.00192 to 0.00190, saving model to gru-5min-4.h5
# Epoch 18/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.9766e-06 - root_mean_squared_error: 0.0026 - val_loss: 3.6277e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00018: val_root_mean_squared_error did not improve from 0.00190
# Epoch 19/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.6835e-06 - root_mean_squared_error: 0.0026 - val_loss: 3.3287e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00019: val_root_mean_squared_error improved from 0.00190 to 0.00182, saving model to gru-5min-4.h5
# Epoch 20/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.5435e-06 - root_mean_squared_error: 0.0026 - val_loss: 3.2047e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00020: val_root_mean_squared_error improved from 0.00182 to 0.00179, saving model to gru-5min-4.h5
# Epoch 21/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.3571e-06 - root_mean_squared_error: 0.0025 - val_loss: 3.6289e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.00179
# Epoch 22/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.3092e-06 - root_mean_squared_error: 0.0025 - val_loss: 3.2416e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.00179
# Epoch 23/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.1948e-06 - root_mean_squared_error: 0.0025 - val_loss: 3.0233e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00023: val_root_mean_squared_error improved from 0.00179 to 0.00174, saving model to gru-5min-4.h5
# Epoch 24/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.0221e-06 - root_mean_squared_error: 0.0025 - val_loss: 3.3066e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.00174
# Epoch 25/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.9098e-06 - root_mean_squared_error: 0.0024 - val_loss: 4.1519e-06 - val_root_mean_squared_error: 0.0020
#
# Epoch 00025: val_root_mean_squared_error did not improve from 0.00174
# Epoch 26/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.9859e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.0557e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.00174
# Epoch 27/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.7982e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.3676e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00027: val_root_mean_squared_error did not improve from 0.00174
# Epoch 28/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.7818e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.7430e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00028: val_root_mean_squared_error improved from 0.00174 to 0.00166, saving model to gru-5min-4.h5
# Epoch 29/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.6040e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.6766e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00029: val_root_mean_squared_error improved from 0.00166 to 0.00164, saving model to gru-5min-4.h5
# Epoch 30/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.5714e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.2471e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.00164
# Epoch 31/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.5430e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.2745e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.00164
# Epoch 32/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.4617e-06 - root_mean_squared_error: 0.0023 - val_loss: 3.6823e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.00164
# Epoch 33/50
# 75/75 [==============================] - ETA: 0s - loss: 5.5128e-06 - root_mean_squared_error: 0.002 - 3s 41ms/step - loss: 5.5289e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.1536e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.00164
# Epoch 34/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.3758e-06 - root_mean_squared_error: 0.0023 - val_loss: 2.8098e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.00164
# Epoch 35/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.5390e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.6029e-06 - val_root_mean_squared_error: 0.0019
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.00164
# Epoch 36/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.4083e-06 - root_mean_squared_error: 0.0023 - val_loss: 3.2906e-06 - val_root_mean_squared_error: 0.0018
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.00164
# Epoch 37/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.2976e-06 - root_mean_squared_error: 0.0023 - val_loss: 4.2237e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00037: val_root_mean_squared_error did not improve from 0.00164
# Epoch 38/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.3452e-06 - root_mean_squared_error: 0.0023 - val_loss: 2.5612e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00038: val_root_mean_squared_error improved from 0.00164 to 0.00160, saving model to gru-5min-4.h5
# Epoch 39/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.1668e-06 - root_mean_squared_error: 0.0023 - val_loss: 6.5940e-06 - val_root_mean_squared_error: 0.0026
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.00160
# Epoch 40/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.9342e-06 - root_mean_squared_error: 0.0024 - val_loss: 4.2093e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00040: val_root_mean_squared_error did not improve from 0.00160
# Epoch 41/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.3352e-06 - root_mean_squared_error: 0.0023 - val_loss: 4.4025e-06 - val_root_mean_squared_error: 0.0021
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.00160
# Epoch 42/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.8682e-06 - root_mean_squared_error: 0.0024 - val_loss: 6.9731e-06 - val_root_mean_squared_error: 0.0026
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.00160
# Epoch 43/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.1045e-06 - root_mean_squared_error: 0.0025 - val_loss: 2.7821e-06 - val_root_mean_squared_error: 0.0017
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.00160
# Epoch 44/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.8230e-06 - root_mean_squared_error: 0.0024 - val_loss: 2.1536e-05 - val_root_mean_squared_error: 0.0046
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.00160
# Epoch 45/50
# 75/75 [==============================] - 3s 41ms/step - loss: 7.4447e-06 - root_mean_squared_error: 0.0027 - val_loss: 1.4706e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.00160
# Epoch 46/50
# 75/75 [==============================] - 3s 41ms/step - loss: 8.4605e-06 - root_mean_squared_error: 0.0029 - val_loss: 2.6301e-06 - val_root_mean_squared_error: 0.0016
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.00160
# Epoch 47/50
# 75/75 [==============================] - 3s 41ms/step - loss: 5.9110e-06 - root_mean_squared_error: 0.0024 - val_loss: 1.0816e-05 - val_root_mean_squared_error: 0.0033
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.00160
# Epoch 48/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.4613e-06 - root_mean_squared_error: 0.0025 - val_loss: 6.1314e-06 - val_root_mean_squared_error: 0.0025
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.00160
# Epoch 49/50
# 75/75 [==============================] - 3s 41ms/step - loss: 6.8966e-06 - root_mean_squared_error: 0.0026 - val_loss: 1.4823e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.00160
# Epoch 50/50
# 75/75 [==============================] - 3s 41ms/step - loss: 1.0561e-05 - root_mean_squared_error: 0.0032 - val_loss: 9.3753e-06 - val_root_mean_squared_error: 0.0031
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.00160

# %%
models = []
for i in range(5):
    # models.append(tf.keras.models.load_model('../Trained_Models/gru'+str(i)+'.h5'))
    models.append(tf.keras.models.load_model('gru-5min-'+str(i)+'.h5'))

# %%
predictions = []
for model in models:
    predictions.append(model.predict(X_test))

# %%
# prediction = model.predict(X_test)
for i, prediction in enumerate(predictions):
    mse = mean_squared_error(y_test, prediction)
    rmse = mean_squared_error(y_test, prediction, squared=False)
    mae = mean_absolute_error(y_test, prediction)

    metrics = '\n'.join((
        '$MSE=%f$' % (mse),
        '$RMSE=%f$' % (rmse),
        '$MAE=%f$' % (mae)
    ))

    plt.figure(figsize=(26, 10))
    plt.plot(prediction, label='Prediction Price')
    plt.plot(y_test, label='Ground Truth')
    plt.legend()
    plt.title('Sub-model ' + str(i+1) + ': Predictions for next 5 min')

    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    plt.text(0.1, 0.2, metrics, fontsize=14,
            verticalalignment='top', bbox=props)

    # plt.savefig('no_senti.png', dpi=500)
    plt.show()

# %%
prediction = np.mean(np.array(predictions), axis=0)
mse = mean_squared_error(y_test, prediction)
rmse = mean_squared_error(y_test, prediction, squared=False)
mae = mean_absolute_error(y_test, prediction)

metrics = '\n'.join((
    '$MSE=%f$' % (mse),
    '$RMSE=%f$' % (rmse),
    '$MAE=%f$' % (mae)
))

plt.figure(figsize=(26, 10))
plt.plot(prediction, label='Prediction Price')
plt.plot(y_test, label='Ground Truth')
plt.legend()
plt.title('Predictions for next 5 min')

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
plt.text(0.1, 0.2, metrics, fontsize=14,
        verticalalignment='top', bbox=props)

# plt.savefig('no_senti.png', dpi=500)
plt.show()

# %%
pred_prices = scaler_label.inverse_transform(prediction)
true_prices = scaler_label.inverse_transform(y_test.reshape(-1,1))

mse = mean_squared_error(true_prices, pred_prices)
rmse = mean_squared_error(true_prices, pred_prices, squared=False)
mae = mean_absolute_error(true_prices, pred_prices)

metrics = '\n'.join((
    '$MSE=%f$' % (mse),
    '$RMSE=%f$' % (rmse),
    '$MAE=%f$' % (mae)
))

plt.figure(figsize=(26, 10))
plt.plot(pred_prices, label='Prediction Price')
plt.plot(true_prices, label='Ground Truth')
plt.legend()
plt.title('(GRU) Predictions for next 5 min')

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
plt.text(0, 40000, metrics, fontsize=14,
        verticalalignment='top', bbox=props)

# plt.savefig('no_senti.png', dpi=500)
plt.show()
