# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from keras import layers
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import numpy as np
import pandas as pd
import matplotlib
import tensorflow as tf
import sklearn

print('numpy==' + np.__version__)
print('pandas==' + pd.__version__)
print('matplotlib==' + matplotlib.__version__)
print('tensorflow-macos==' + tf.__version__)
print('sklearn==' + sklearn.__version__)
# Out:
# numpy==1.19.5
# pandas==1.3.2
# matplotlib==3.4.3
# tensorflow-macos==2.6.0
# sklearn==1.1.1

# %%
data_path = 'data/tweets_sentiment_score_price_30min_20210205_20220218.csv'
data = pd.read_csv(data_path).drop(['30min_TimeStart', 'time_period_end', 'time_open', 'time_close'], axis=1)

data.head()
# Out:
#    vander_pos  vander_neg  vander_neu  vander_compound  textblob_polarity  \
# 0    0.100190    0.018444    0.881365         0.216578           0.121243
# 1    0.091883    0.030233    0.877883         0.199323           0.097247
# 2    0.094134    0.028612    0.877299         0.138354           0.133878
# 3    0.103039    0.036224    0.860763         0.123916           0.082325
# 4    0.065413    0.031739    0.902870         0.088252           0.065734
#
#    textblob_subjectivity  price_open  price_high  price_low  price_close  \
# 0               0.413583    38320.00    38653.07   38230.81     38433.23
# 1               0.350694    38422.06    38881.31   38398.27     38758.56
# 2               0.325827    38779.87    39411.00   38620.27     39360.12
# 3               0.287223    39362.43    39492.25   38343.93     38871.15
# 4               0.222612    38858.47    39115.16   38660.34     38999.45
#
#    volume_traded  trades_count
# 0     242.715847          1357
# 1     151.544974           956
# 2     451.455618          1806
# 3     425.500335          1773
# 4      96.015329           583

# %%
data_features = data.drop(['price_close'], axis=1)
data_labels = data['price_close']

# data = data.to_numpy()

scaler_feature = MinMaxScaler(feature_range=(0, 1))
scaler_label = MinMaxScaler(feature_range=(0, 1))

feature = scaler_feature.fit_transform(data_features.to_numpy())
label = scaler_label.fit_transform(data_labels.to_numpy().reshape(-1, 1))


train_size1 = int(0.7 * len(label))
train_size2 = int(0.9 * len(label))

# %%
print(data_features[:3])
print(data_labels[:3])
# Out:
#    vander_pos  vander_neg  vander_neu  vander_compound  textblob_polarity  \
# 0    0.100190    0.018444    0.881365         0.216578           0.121243
# 1    0.091883    0.030233    0.877883         0.199323           0.097247
# 2    0.094134    0.028612    0.877299         0.138354           0.133878
#
#    textblob_subjectivity  price_open  price_high  price_low  volume_traded  \
# 0               0.413583    38320.00    38653.07   38230.81     242.715847
# 1               0.350694    38422.06    38881.31   38398.27     151.544974
# 2               0.325827    38779.87    39411.00   38620.27     451.455618
#
#    trades_count
# 0          1357
# 1           956
# 2          1806
# 0    38433.23
# 1    38758.56
# 2    39360.12
# Name: price_close, dtype: float64

# %%
def split_data(f, l):
    delay = 15 * 2
    feature, label = [], []

    for i in range(len(f) - delay):
        feature.append(f[i: i + delay])
        label.append(l[i + delay-1])
        
    return np.array(feature), np.array(label).squeeze()

X_train, y_train = split_data(feature[:train_size1], label[:train_size1])
X_train2, y_train2 = split_data(feature[train_size1:train_size2], label[train_size1:train_size2])
X_test, y_test = split_data(feature[train_size2:], label[train_size2:])

# %%
models = [
    keras.Sequential([
        layers.GRU(128),
        layers.Dense(1)
    ]) for i in range(5)
]
# Out:
# 2022-09-07 08:40:03.116366: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:40:03.123105: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:40:03.123292: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:40:03.124000: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-07 08:40:03.124293: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:40:03.124458: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:40:03.124604: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:40:03.556466: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:40:03.556654: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:40:03.556798: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 08:40:03.556916: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4580 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
for i, model in enumerate(models):
    model.compile(loss='mean_squared_error',
                  optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.00005),
                  metrics=[keras.metrics.RootMeanSquaredError()]
                  )
    history = model.fit(X_train, y_train,
                        epochs=50,
                        batch_size=256,
                        validation_data=(X_test, y_test),
                        callbacks=[keras.callbacks.ModelCheckpoint('gru-30min-'+str(i)+'.h5', verbose=1, monitor='val_root_mean_squared_error',save_best_only=True, mode='auto')],
                        shuffle=True
                        )
# Out:
# /home/charles/.local/lib/python3.8/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 2022-09-07 08:40:03.711855: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2022-09-07 08:40:05.303724: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8400
# 50/50 [==============================] - 2s 9ms/step - loss: 0.0324 - root_mean_squared_error: 0.1800 - val_loss: 4.8344e-05 - val_root_mean_squared_error: 0.0070
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.00695, saving model to gru-30min-0.h5
# Epoch 2/50
# 50/50 [==============================] - 0s 4ms/step - loss: 1.8204e-04 - root_mean_squared_error: 0.0135 - val_loss: 5.4606e-05 - val_root_mean_squared_error: 0.0074
#
# Epoch 00002: val_root_mean_squared_error did not improve from 0.00695
# Epoch 3/50
# 50/50 [==============================] - 0s 4ms/step - loss: 8.0669e-05 - root_mean_squared_error: 0.0090 - val_loss: 4.1123e-05 - val_root_mean_squared_error: 0.0064
#
# Epoch 00003: val_root_mean_squared_error improved from 0.00695 to 0.00641, saving model to gru-30min-0.h5
# Epoch 4/50
# 50/50 [==============================] - 0s 4ms/step - loss: 7.0970e-05 - root_mean_squared_error: 0.0084 - val_loss: 3.6169e-05 - val_root_mean_squared_error: 0.0060
#
# Epoch 00004: val_root_mean_squared_error improved from 0.00641 to 0.00601, saving model to gru-30min-0.h5
# Epoch 5/50
# 50/50 [==============================] - 0s 4ms/step - loss: 6.3895e-05 - root_mean_squared_error: 0.0080 - val_loss: 3.1651e-05 - val_root_mean_squared_error: 0.0056
#
# Epoch 00005: val_root_mean_squared_error improved from 0.00601 to 0.00563, saving model to gru-30min-0.h5
# Epoch 6/50
# 50/50 [==============================] - 0s 4ms/step - loss: 5.8190e-05 - root_mean_squared_error: 0.0076 - val_loss: 2.8486e-05 - val_root_mean_squared_error: 0.0053
#
# Epoch 00006: val_root_mean_squared_error improved from 0.00563 to 0.00534, saving model to gru-30min-0.h5
# Epoch 7/50
# 50/50 [==============================] - 0s 4ms/step - loss: 5.3456e-05 - root_mean_squared_error: 0.0073 - val_loss: 2.6485e-05 - val_root_mean_squared_error: 0.0051
#
# Epoch 00007: val_root_mean_squared_error improved from 0.00534 to 0.00515, saving model to gru-30min-0.h5
# Epoch 8/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.9298e-05 - root_mean_squared_error: 0.0070 - val_loss: 2.5202e-05 - val_root_mean_squared_error: 0.0050
#
# Epoch 00008: val_root_mean_squared_error improved from 0.00515 to 0.00502, saving model to gru-30min-0.h5
# Epoch 9/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.6028e-05 - root_mean_squared_error: 0.0068 - val_loss: 2.2947e-05 - val_root_mean_squared_error: 0.0048
#
# Epoch 00009: val_root_mean_squared_error improved from 0.00502 to 0.00479, saving model to gru-30min-0.h5
# Epoch 10/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.3115e-05 - root_mean_squared_error: 0.0066 - val_loss: 2.3265e-05 - val_root_mean_squared_error: 0.0048
#
# Epoch 00010: val_root_mean_squared_error did not improve from 0.00479
# Epoch 11/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.1131e-05 - root_mean_squared_error: 0.0064 - val_loss: 2.1079e-05 - val_root_mean_squared_error: 0.0046
#
# Epoch 00011: val_root_mean_squared_error improved from 0.00479 to 0.00459, saving model to gru-30min-0.h5
# Epoch 12/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.9301e-05 - root_mean_squared_error: 0.0063 - val_loss: 2.0247e-05 - val_root_mean_squared_error: 0.0045
#
# Epoch 00012: val_root_mean_squared_error improved from 0.00459 to 0.00450, saving model to gru-30min-0.h5
# Epoch 13/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.7919e-05 - root_mean_squared_error: 0.0062 - val_loss: 1.9246e-05 - val_root_mean_squared_error: 0.0044
#
# Epoch 00013: val_root_mean_squared_error improved from 0.00450 to 0.00439, saving model to gru-30min-0.h5
# Epoch 14/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.6471e-05 - root_mean_squared_error: 0.0060 - val_loss: 1.8598e-05 - val_root_mean_squared_error: 0.0043
#
# Epoch 00014: val_root_mean_squared_error improved from 0.00439 to 0.00431, saving model to gru-30min-0.h5
# Epoch 15/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.5599e-05 - root_mean_squared_error: 0.0060 - val_loss: 1.7853e-05 - val_root_mean_squared_error: 0.0042
#
# Epoch 00015: val_root_mean_squared_error improved from 0.00431 to 0.00423, saving model to gru-30min-0.h5
# Epoch 16/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.4688e-05 - root_mean_squared_error: 0.0059 - val_loss: 1.7631e-05 - val_root_mean_squared_error: 0.0042
#
# Epoch 00016: val_root_mean_squared_error improved from 0.00423 to 0.00420, saving model to gru-30min-0.h5
# Epoch 17/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.3730e-05 - root_mean_squared_error: 0.0058 - val_loss: 1.6886e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00017: val_root_mean_squared_error improved from 0.00420 to 0.00411, saving model to gru-30min-0.h5
# Epoch 18/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.2892e-05 - root_mean_squared_error: 0.0057 - val_loss: 1.6576e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00018: val_root_mean_squared_error improved from 0.00411 to 0.00407, saving model to gru-30min-0.h5
# Epoch 19/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.2381e-05 - root_mean_squared_error: 0.0057 - val_loss: 1.6046e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00019: val_root_mean_squared_error improved from 0.00407 to 0.00401, saving model to gru-30min-0.h5
# Epoch 20/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.1681e-05 - root_mean_squared_error: 0.0056 - val_loss: 1.5673e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00020: val_root_mean_squared_error improved from 0.00401 to 0.00396, saving model to gru-30min-0.h5
# Epoch 21/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.0999e-05 - root_mean_squared_error: 0.0056 - val_loss: 1.5425e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00021: val_root_mean_squared_error improved from 0.00396 to 0.00393, saving model to gru-30min-0.h5
# Epoch 22/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.0641e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.5236e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00022: val_root_mean_squared_error improved from 0.00393 to 0.00390, saving model to gru-30min-0.h5
# Epoch 23/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.0171e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.5292e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.00390
# Epoch 24/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.9799e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.5038e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00024: val_root_mean_squared_error improved from 0.00390 to 0.00388, saving model to gru-30min-0.h5
# Epoch 25/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.9309e-05 - root_mean_squared_error: 0.0054 - val_loss: 1.4764e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00025: val_root_mean_squared_error improved from 0.00388 to 0.00384, saving model to gru-30min-0.h5
# Epoch 26/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.9251e-05 - root_mean_squared_error: 0.0054 - val_loss: 1.4939e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.00384
# Epoch 27/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8603e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.4174e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00027: val_root_mean_squared_error improved from 0.00384 to 0.00376, saving model to gru-30min-0.h5
# Epoch 28/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8585e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.4019e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00028: val_root_mean_squared_error improved from 0.00376 to 0.00374, saving model to gru-30min-0.h5
# Epoch 29/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7866e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.3725e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00029: val_root_mean_squared_error improved from 0.00374 to 0.00370, saving model to gru-30min-0.h5
# Epoch 30/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7671e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.4136e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.00370
# Epoch 31/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7625e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.3832e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.00370
# Epoch 32/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7731e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.3586e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00032: val_root_mean_squared_error improved from 0.00370 to 0.00369, saving model to gru-30min-0.h5
# Epoch 33/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7634e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.4649e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.00369
# Epoch 34/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7134e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.2989e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00034: val_root_mean_squared_error improved from 0.00369 to 0.00360, saving model to gru-30min-0.h5
# Epoch 35/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6789e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.3399e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.00360
# Epoch 36/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6501e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.2848e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00036: val_root_mean_squared_error improved from 0.00360 to 0.00358, saving model to gru-30min-0.h5
# Epoch 37/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6291e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.2706e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00037: val_root_mean_squared_error improved from 0.00358 to 0.00356, saving model to gru-30min-0.h5
# Epoch 38/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5797e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.2724e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.00356
# Epoch 39/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5683e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.2616e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00039: val_root_mean_squared_error improved from 0.00356 to 0.00355, saving model to gru-30min-0.h5
# Epoch 40/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5746e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.2614e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00040: val_root_mean_squared_error improved from 0.00355 to 0.00355, saving model to gru-30min-0.h5
# Epoch 41/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5482e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.2272e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00041: val_root_mean_squared_error improved from 0.00355 to 0.00350, saving model to gru-30min-0.h5
# Epoch 42/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6491e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.3361e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.00350
# Epoch 43/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5568e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.2724e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.00350
# Epoch 44/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6802e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.2463e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.00350
# Epoch 45/50
# 50/50 [==============================] - 0s 5ms/step - loss: 2.4785e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.3111e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.00350
# Epoch 46/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5138e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.2042e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00046: val_root_mean_squared_error improved from 0.00350 to 0.00347, saving model to gru-30min-0.h5
# Epoch 47/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.4758e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.2112e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.00347
# Epoch 48/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.4342e-05 - root_mean_squared_error: 0.0049 - val_loss: 1.3147e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.00347
# Epoch 49/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.4247e-05 - root_mean_squared_error: 0.0049 - val_loss: 1.6369e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.00347
# Epoch 50/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.4354e-05 - root_mean_squared_error: 0.0049 - val_loss: 1.1533e-05 - val_root_mean_squared_error: 0.0034
#
# Epoch 00050: val_root_mean_squared_error improved from 0.00347 to 0.00340, saving model to gru-30min-0.h5
# Epoch 1/50
# 50/50 [==============================] - 1s 8ms/step - loss: 0.0208 - root_mean_squared_error: 0.1442 - val_loss: 1.0076e-04 - val_root_mean_squared_error: 0.0100
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.01004, saving model to gru-30min-1.h5
# Epoch 2/50
# 50/50 [==============================] - 0s 4ms/step - loss: 1.5012e-04 - root_mean_squared_error: 0.0123 - val_loss: 4.1572e-05 - val_root_mean_squared_error: 0.0064
#
# Epoch 00002: val_root_mean_squared_error improved from 0.01004 to 0.00645, saving model to gru-30min-1.h5
# Epoch 3/50
# 50/50 [==============================] - 0s 4ms/step - loss: 7.9321e-05 - root_mean_squared_error: 0.0089 - val_loss: 3.9573e-05 - val_root_mean_squared_error: 0.0063
#
# Epoch 00003: val_root_mean_squared_error improved from 0.00645 to 0.00629, saving model to gru-30min-1.h5
# Epoch 4/50
# 50/50 [==============================] - 0s 4ms/step - loss: 7.0506e-05 - root_mean_squared_error: 0.0084 - val_loss: 3.7390e-05 - val_root_mean_squared_error: 0.0061
#
# Epoch 00004: val_root_mean_squared_error improved from 0.00629 to 0.00611, saving model to gru-30min-1.h5
# Epoch 5/50
# 50/50 [==============================] - 0s 4ms/step - loss: 6.3707e-05 - root_mean_squared_error: 0.0080 - val_loss: 3.5305e-05 - val_root_mean_squared_error: 0.0059
#
# Epoch 00005: val_root_mean_squared_error improved from 0.00611 to 0.00594, saving model to gru-30min-1.h5
# Epoch 6/50
# 50/50 [==============================] - 0s 4ms/step - loss: 5.8553e-05 - root_mean_squared_error: 0.0077 - val_loss: 3.1652e-05 - val_root_mean_squared_error: 0.0056
#
# Epoch 00006: val_root_mean_squared_error improved from 0.00594 to 0.00563, saving model to gru-30min-1.h5
# Epoch 7/50
# 50/50 [==============================] - 0s 4ms/step - loss: 5.4353e-05 - root_mean_squared_error: 0.0074 - val_loss: 2.8040e-05 - val_root_mean_squared_error: 0.0053
#
# Epoch 00007: val_root_mean_squared_error improved from 0.00563 to 0.00530, saving model to gru-30min-1.h5
# Epoch 8/50
# 50/50 [==============================] - 0s 4ms/step - loss: 5.0821e-05 - root_mean_squared_error: 0.0071 - val_loss: 2.7143e-05 - val_root_mean_squared_error: 0.0052
#
# Epoch 00008: val_root_mean_squared_error improved from 0.00530 to 0.00521, saving model to gru-30min-1.h5
# Epoch 9/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.7835e-05 - root_mean_squared_error: 0.0069 - val_loss: 2.4619e-05 - val_root_mean_squared_error: 0.0050
#
# Epoch 00009: val_root_mean_squared_error improved from 0.00521 to 0.00496, saving model to gru-30min-1.h5
# Epoch 10/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.5557e-05 - root_mean_squared_error: 0.0067 - val_loss: 2.3604e-05 - val_root_mean_squared_error: 0.0049
#
# Epoch 00010: val_root_mean_squared_error improved from 0.00496 to 0.00486, saving model to gru-30min-1.h5
# Epoch 11/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.3781e-05 - root_mean_squared_error: 0.0066 - val_loss: 2.2783e-05 - val_root_mean_squared_error: 0.0048
#
# Epoch 00011: val_root_mean_squared_error improved from 0.00486 to 0.00477, saving model to gru-30min-1.h5
# Epoch 12/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.1787e-05 - root_mean_squared_error: 0.0065 - val_loss: 2.4040e-05 - val_root_mean_squared_error: 0.0049
#
# Epoch 00012: val_root_mean_squared_error did not improve from 0.00477
# Epoch 13/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.0390e-05 - root_mean_squared_error: 0.0064 - val_loss: 2.0848e-05 - val_root_mean_squared_error: 0.0046
#
# Epoch 00013: val_root_mean_squared_error improved from 0.00477 to 0.00457, saving model to gru-30min-1.h5
# Epoch 14/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.9088e-05 - root_mean_squared_error: 0.0063 - val_loss: 2.0277e-05 - val_root_mean_squared_error: 0.0045
#
# Epoch 00014: val_root_mean_squared_error improved from 0.00457 to 0.00450, saving model to gru-30min-1.h5
# Epoch 15/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.7770e-05 - root_mean_squared_error: 0.0061 - val_loss: 1.9354e-05 - val_root_mean_squared_error: 0.0044
#
# Epoch 00015: val_root_mean_squared_error improved from 0.00450 to 0.00440, saving model to gru-30min-1.h5
# Epoch 16/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.6803e-05 - root_mean_squared_error: 0.0061 - val_loss: 1.9363e-05 - val_root_mean_squared_error: 0.0044
#
# Epoch 00016: val_root_mean_squared_error did not improve from 0.00440
# Epoch 17/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.6622e-05 - root_mean_squared_error: 0.0061 - val_loss: 1.8402e-05 - val_root_mean_squared_error: 0.0043
#
# Epoch 00017: val_root_mean_squared_error improved from 0.00440 to 0.00429, saving model to gru-30min-1.h5
# Epoch 18/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.4954e-05 - root_mean_squared_error: 0.0059 - val_loss: 1.8519e-05 - val_root_mean_squared_error: 0.0043
#
# Epoch 00018: val_root_mean_squared_error did not improve from 0.00429
# Epoch 19/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.4218e-05 - root_mean_squared_error: 0.0058 - val_loss: 2.0628e-05 - val_root_mean_squared_error: 0.0045
#
# Epoch 00019: val_root_mean_squared_error did not improve from 0.00429
# Epoch 20/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.3841e-05 - root_mean_squared_error: 0.0058 - val_loss: 1.7209e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00020: val_root_mean_squared_error improved from 0.00429 to 0.00415, saving model to gru-30min-1.h5
# Epoch 21/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.3178e-05 - root_mean_squared_error: 0.0058 - val_loss: 1.5624e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00021: val_root_mean_squared_error improved from 0.00415 to 0.00395, saving model to gru-30min-1.h5
# Epoch 22/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.2380e-05 - root_mean_squared_error: 0.0057 - val_loss: 1.5776e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.00395
# Epoch 23/50
# 50/50 [==============================] - 0s 3ms/step - loss: 3.1607e-05 - root_mean_squared_error: 0.0056 - val_loss: 1.6458e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.00395
# Epoch 24/50
# 50/50 [==============================] - 0s 5ms/step - loss: 3.0941e-05 - root_mean_squared_error: 0.0056 - val_loss: 1.5102e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00024: val_root_mean_squared_error improved from 0.00395 to 0.00389, saving model to gru-30min-1.h5
# Epoch 25/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.0945e-05 - root_mean_squared_error: 0.0056 - val_loss: 1.7419e-05 - val_root_mean_squared_error: 0.0042
#
# Epoch 00025: val_root_mean_squared_error did not improve from 0.00389
# Epoch 26/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.0232e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.4651e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00026: val_root_mean_squared_error improved from 0.00389 to 0.00383, saving model to gru-30min-1.h5
# Epoch 27/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.0366e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.7298e-05 - val_root_mean_squared_error: 0.0042
#
# Epoch 00027: val_root_mean_squared_error did not improve from 0.00383
# Epoch 28/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.9827e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.4384e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00028: val_root_mean_squared_error improved from 0.00383 to 0.00379, saving model to gru-30min-1.h5
# Epoch 29/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.9097e-05 - root_mean_squared_error: 0.0054 - val_loss: 1.4541e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.00379
# Epoch 30/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8623e-05 - root_mean_squared_error: 0.0054 - val_loss: 1.4991e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.00379
# Epoch 31/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8933e-05 - root_mean_squared_error: 0.0054 - val_loss: 1.5342e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.00379
# Epoch 32/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7771e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.4366e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00032: val_root_mean_squared_error improved from 0.00379 to 0.00379, saving model to gru-30min-1.h5
# Epoch 33/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7528e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.4237e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00033: val_root_mean_squared_error improved from 0.00379 to 0.00377, saving model to gru-30min-1.h5
# Epoch 34/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7734e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.9156e-05 - val_root_mean_squared_error: 0.0044
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.00377
# Epoch 35/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7722e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.2844e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00035: val_root_mean_squared_error improved from 0.00377 to 0.00358, saving model to gru-30min-1.h5
# Epoch 36/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6904e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.4117e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.00358
# Epoch 37/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6566e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.7296e-05 - val_root_mean_squared_error: 0.0042
#
# Epoch 00037: val_root_mean_squared_error did not improve from 0.00358
# Epoch 38/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6985e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.4055e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.00358
# Epoch 39/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6631e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.3741e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.00358
# Epoch 40/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6717e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.2493e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00040: val_root_mean_squared_error improved from 0.00358 to 0.00353, saving model to gru-30min-1.h5
# Epoch 41/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6479e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.2264e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00041: val_root_mean_squared_error improved from 0.00353 to 0.00350, saving model to gru-30min-1.h5
# Epoch 42/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5543e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.2370e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.00350
# Epoch 43/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5297e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.2483e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.00350
# Epoch 44/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5540e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.2010e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00044: val_root_mean_squared_error improved from 0.00350 to 0.00347, saving model to gru-30min-1.h5
# Epoch 45/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5017e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.2495e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.00347
# Epoch 46/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.4602e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.1515e-05 - val_root_mean_squared_error: 0.0034
#
# Epoch 00046: val_root_mean_squared_error improved from 0.00347 to 0.00339, saving model to gru-30min-1.h5
# Epoch 47/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5040e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.1976e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.00339
# Epoch 48/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.4903e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.3309e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.00339
# Epoch 49/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.4661e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.1927e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.00339
# Epoch 50/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.3739e-05 - root_mean_squared_error: 0.0049 - val_loss: 1.5693e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.00339
# Epoch 1/50
# 50/50 [==============================] - 1s 8ms/step - loss: 0.0073 - root_mean_squared_error: 0.0852 - val_loss: 8.6035e-05 - val_root_mean_squared_error: 0.0093
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.00928, saving model to gru-30min-2.h5
# Epoch 2/50
# 50/50 [==============================] - 0s 5ms/step - loss: 1.3782e-04 - root_mean_squared_error: 0.0117 - val_loss: 4.2253e-05 - val_root_mean_squared_error: 0.0065
#
# Epoch 00002: val_root_mean_squared_error improved from 0.00928 to 0.00650, saving model to gru-30min-2.h5
# Epoch 3/50
# 50/50 [==============================] - 0s 4ms/step - loss: 7.7636e-05 - root_mean_squared_error: 0.0088 - val_loss: 3.6837e-05 - val_root_mean_squared_error: 0.0061
#
# Epoch 00003: val_root_mean_squared_error improved from 0.00650 to 0.00607, saving model to gru-30min-2.h5
# Epoch 4/50
# 50/50 [==============================] - 0s 4ms/step - loss: 6.3683e-05 - root_mean_squared_error: 0.0080 - val_loss: 2.9604e-05 - val_root_mean_squared_error: 0.0054
#
# Epoch 00004: val_root_mean_squared_error improved from 0.00607 to 0.00544, saving model to gru-30min-2.h5
# Epoch 5/50
# 50/50 [==============================] - 0s 4ms/step - loss: 5.6282e-05 - root_mean_squared_error: 0.0075 - val_loss: 2.9329e-05 - val_root_mean_squared_error: 0.0054
#
# Epoch 00005: val_root_mean_squared_error improved from 0.00544 to 0.00542, saving model to gru-30min-2.h5
# Epoch 6/50
# 50/50 [==============================] - 0s 4ms/step - loss: 5.0554e-05 - root_mean_squared_error: 0.0071 - val_loss: 2.6051e-05 - val_root_mean_squared_error: 0.0051
#
# Epoch 00006: val_root_mean_squared_error improved from 0.00542 to 0.00510, saving model to gru-30min-2.h5
# Epoch 7/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.6902e-05 - root_mean_squared_error: 0.0068 - val_loss: 2.2896e-05 - val_root_mean_squared_error: 0.0048
#
# Epoch 00007: val_root_mean_squared_error improved from 0.00510 to 0.00478, saving model to gru-30min-2.h5
# Epoch 8/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.3931e-05 - root_mean_squared_error: 0.0066 - val_loss: 2.2143e-05 - val_root_mean_squared_error: 0.0047
#
# Epoch 00008: val_root_mean_squared_error improved from 0.00478 to 0.00471, saving model to gru-30min-2.h5
# Epoch 9/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.1670e-05 - root_mean_squared_error: 0.0065 - val_loss: 2.3860e-05 - val_root_mean_squared_error: 0.0049
#
# Epoch 00009: val_root_mean_squared_error did not improve from 0.00471
# Epoch 10/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.0049e-05 - root_mean_squared_error: 0.0063 - val_loss: 1.9568e-05 - val_root_mean_squared_error: 0.0044
#
# Epoch 00010: val_root_mean_squared_error improved from 0.00471 to 0.00442, saving model to gru-30min-2.h5
# Epoch 11/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.8267e-05 - root_mean_squared_error: 0.0062 - val_loss: 2.0589e-05 - val_root_mean_squared_error: 0.0045
#
# Epoch 00011: val_root_mean_squared_error did not improve from 0.00442
# Epoch 12/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.6649e-05 - root_mean_squared_error: 0.0061 - val_loss: 1.8078e-05 - val_root_mean_squared_error: 0.0043
#
# Epoch 00012: val_root_mean_squared_error improved from 0.00442 to 0.00425, saving model to gru-30min-2.h5
# Epoch 13/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.5739e-05 - root_mean_squared_error: 0.0060 - val_loss: 1.8292e-05 - val_root_mean_squared_error: 0.0043
#
# Epoch 00013: val_root_mean_squared_error did not improve from 0.00425
# Epoch 14/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.4563e-05 - root_mean_squared_error: 0.0059 - val_loss: 1.6895e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00014: val_root_mean_squared_error improved from 0.00425 to 0.00411, saving model to gru-30min-2.h5
# Epoch 15/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.3500e-05 - root_mean_squared_error: 0.0058 - val_loss: 1.6969e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00015: val_root_mean_squared_error did not improve from 0.00411
# Epoch 16/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.2470e-05 - root_mean_squared_error: 0.0057 - val_loss: 1.5634e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00016: val_root_mean_squared_error improved from 0.00411 to 0.00395, saving model to gru-30min-2.h5
# Epoch 17/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.1954e-05 - root_mean_squared_error: 0.0057 - val_loss: 1.5866e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00017: val_root_mean_squared_error did not improve from 0.00395
# Epoch 18/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.1621e-05 - root_mean_squared_error: 0.0056 - val_loss: 1.9873e-05 - val_root_mean_squared_error: 0.0045
#
# Epoch 00018: val_root_mean_squared_error did not improve from 0.00395
# Epoch 19/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.1622e-05 - root_mean_squared_error: 0.0056 - val_loss: 1.4701e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00019: val_root_mean_squared_error improved from 0.00395 to 0.00383, saving model to gru-30min-2.h5
# Epoch 20/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.9911e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.4577e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00020: val_root_mean_squared_error improved from 0.00383 to 0.00382, saving model to gru-30min-2.h5
# Epoch 21/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.0034e-05 - root_mean_squared_error: 0.0055 - val_loss: 2.0786e-05 - val_root_mean_squared_error: 0.0046
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.00382
# Epoch 22/50
# 50/50 [==============================] - 0s 3ms/step - loss: 2.9767e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.4265e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00022: val_root_mean_squared_error improved from 0.00382 to 0.00378, saving model to gru-30min-2.h5
# Epoch 23/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8470e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.5877e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.00378
# Epoch 24/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8191e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.3979e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00024: val_root_mean_squared_error improved from 0.00378 to 0.00374, saving model to gru-30min-2.h5
# Epoch 25/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8096e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.3711e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00025: val_root_mean_squared_error improved from 0.00374 to 0.00370, saving model to gru-30min-2.h5
# Epoch 26/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7768e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.4085e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.00370
# Epoch 27/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7427e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.7342e-05 - val_root_mean_squared_error: 0.0042
#
# Epoch 00027: val_root_mean_squared_error did not improve from 0.00370
# Epoch 28/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7415e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.4138e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00028: val_root_mean_squared_error did not improve from 0.00370
# Epoch 29/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7696e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.2524e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00029: val_root_mean_squared_error improved from 0.00370 to 0.00354, saving model to gru-30min-2.h5
# Epoch 30/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6161e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.2317e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00030: val_root_mean_squared_error improved from 0.00354 to 0.00351, saving model to gru-30min-2.h5
# Epoch 31/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6213e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.2838e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.00351
# Epoch 32/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5546e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.3817e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.00351
# Epoch 33/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6112e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.2454e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.00351
# Epoch 34/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.4986e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.2142e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00034: val_root_mean_squared_error improved from 0.00351 to 0.00348, saving model to gru-30min-2.h5
# Epoch 35/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5408e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.2906e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.00348
# Epoch 36/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5250e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.1687e-05 - val_root_mean_squared_error: 0.0034
#
# Epoch 00036: val_root_mean_squared_error improved from 0.00348 to 0.00342, saving model to gru-30min-2.h5
# Epoch 37/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.4514e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.5715e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00037: val_root_mean_squared_error did not improve from 0.00342
# Epoch 38/50
# 50/50 [==============================] - 0s 3ms/step - loss: 2.4587e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.3597e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.00342
# Epoch 39/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.4326e-05 - root_mean_squared_error: 0.0049 - val_loss: 1.3236e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.00342
# Epoch 40/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5926e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.1505e-05 - val_root_mean_squared_error: 0.0034
#
# Epoch 00040: val_root_mean_squared_error improved from 0.00342 to 0.00339, saving model to gru-30min-2.h5
# Epoch 41/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.3389e-05 - root_mean_squared_error: 0.0048 - val_loss: 1.2355e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.00339
# Epoch 42/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5319e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.4958e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.00339
# Epoch 43/50
# 50/50 [==============================] - 0s 5ms/step - loss: 2.5920e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.1493e-05 - val_root_mean_squared_error: 0.0034
#
# Epoch 00043: val_root_mean_squared_error improved from 0.00339 to 0.00339, saving model to gru-30min-2.h5
# Epoch 44/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.3822e-05 - root_mean_squared_error: 0.0049 - val_loss: 1.5030e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.00339
# Epoch 45/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8657e-05 - root_mean_squared_error: 0.0054 - val_loss: 1.5086e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.00339
# Epoch 46/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.3912e-05 - root_mean_squared_error: 0.0049 - val_loss: 3.2816e-05 - val_root_mean_squared_error: 0.0057
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.00339
# Epoch 47/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.4852e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.2402e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.00339
# Epoch 48/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6747e-05 - root_mean_squared_error: 0.0052 - val_loss: 3.7449e-05 - val_root_mean_squared_error: 0.0061
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.00339
# Epoch 49/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5929e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.5148e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.00339
# Epoch 50/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8424e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.8626e-05 - val_root_mean_squared_error: 0.0043
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.00339
# Epoch 1/50
# 50/50 [==============================] - 1s 8ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 1.6063e-04 - val_root_mean_squared_error: 0.0127
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.01267, saving model to gru-30min-3.h5
# Epoch 2/50
# 50/50 [==============================] - 0s 4ms/step - loss: 1.7129e-04 - root_mean_squared_error: 0.0131 - val_loss: 5.1610e-05 - val_root_mean_squared_error: 0.0072
#
# Epoch 00002: val_root_mean_squared_error improved from 0.01267 to 0.00718, saving model to gru-30min-3.h5
# Epoch 3/50
# 50/50 [==============================] - 0s 4ms/step - loss: 9.9406e-05 - root_mean_squared_error: 0.0100 - val_loss: 4.8929e-05 - val_root_mean_squared_error: 0.0070
#
# Epoch 00003: val_root_mean_squared_error improved from 0.00718 to 0.00699, saving model to gru-30min-3.h5
# Epoch 4/50
# 50/50 [==============================] - 0s 4ms/step - loss: 8.3166e-05 - root_mean_squared_error: 0.0091 - val_loss: 4.5844e-05 - val_root_mean_squared_error: 0.0068
#
# Epoch 00004: val_root_mean_squared_error improved from 0.00699 to 0.00677, saving model to gru-30min-3.h5
# Epoch 5/50
# 50/50 [==============================] - 0s 4ms/step - loss: 7.2108e-05 - root_mean_squared_error: 0.0085 - val_loss: 4.2889e-05 - val_root_mean_squared_error: 0.0065
#
# Epoch 00005: val_root_mean_squared_error improved from 0.00677 to 0.00655, saving model to gru-30min-3.h5
# Epoch 6/50
# 50/50 [==============================] - 0s 4ms/step - loss: 6.3755e-05 - root_mean_squared_error: 0.0080 - val_loss: 4.0673e-05 - val_root_mean_squared_error: 0.0064
#
# Epoch 00006: val_root_mean_squared_error improved from 0.00655 to 0.00638, saving model to gru-30min-3.h5
# Epoch 7/50
# 50/50 [==============================] - 0s 4ms/step - loss: 5.7453e-05 - root_mean_squared_error: 0.0076 - val_loss: 3.6353e-05 - val_root_mean_squared_error: 0.0060
#
# Epoch 00007: val_root_mean_squared_error improved from 0.00638 to 0.00603, saving model to gru-30min-3.h5
# Epoch 8/50
# 50/50 [==============================] - 0s 4ms/step - loss: 5.2748e-05 - root_mean_squared_error: 0.0073 - val_loss: 3.2918e-05 - val_root_mean_squared_error: 0.0057
#
# Epoch 00008: val_root_mean_squared_error improved from 0.00603 to 0.00574, saving model to gru-30min-3.h5
# Epoch 9/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.9033e-05 - root_mean_squared_error: 0.0070 - val_loss: 2.9039e-05 - val_root_mean_squared_error: 0.0054
#
# Epoch 00009: val_root_mean_squared_error improved from 0.00574 to 0.00539, saving model to gru-30min-3.h5
# Epoch 10/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.5977e-05 - root_mean_squared_error: 0.0068 - val_loss: 2.8315e-05 - val_root_mean_squared_error: 0.0053
#
# Epoch 00010: val_root_mean_squared_error improved from 0.00539 to 0.00532, saving model to gru-30min-3.h5
# Epoch 11/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.3511e-05 - root_mean_squared_error: 0.0066 - val_loss: 2.5379e-05 - val_root_mean_squared_error: 0.0050
#
# Epoch 00011: val_root_mean_squared_error improved from 0.00532 to 0.00504, saving model to gru-30min-3.h5
# Epoch 12/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.1663e-05 - root_mean_squared_error: 0.0065 - val_loss: 2.4366e-05 - val_root_mean_squared_error: 0.0049
#
# Epoch 00012: val_root_mean_squared_error improved from 0.00504 to 0.00494, saving model to gru-30min-3.h5
# Epoch 13/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.9651e-05 - root_mean_squared_error: 0.0063 - val_loss: 2.2072e-05 - val_root_mean_squared_error: 0.0047
#
# Epoch 00013: val_root_mean_squared_error improved from 0.00494 to 0.00470, saving model to gru-30min-3.h5
# Epoch 14/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.8522e-05 - root_mean_squared_error: 0.0062 - val_loss: 2.1746e-05 - val_root_mean_squared_error: 0.0047
#
# Epoch 00014: val_root_mean_squared_error improved from 0.00470 to 0.00466, saving model to gru-30min-3.h5
# Epoch 15/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.7098e-05 - root_mean_squared_error: 0.0061 - val_loss: 1.9810e-05 - val_root_mean_squared_error: 0.0045
#
# Epoch 00015: val_root_mean_squared_error improved from 0.00466 to 0.00445, saving model to gru-30min-3.h5
# Epoch 16/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.6076e-05 - root_mean_squared_error: 0.0060 - val_loss: 1.9454e-05 - val_root_mean_squared_error: 0.0044
#
# Epoch 00016: val_root_mean_squared_error improved from 0.00445 to 0.00441, saving model to gru-30min-3.h5
# Epoch 17/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.4780e-05 - root_mean_squared_error: 0.0059 - val_loss: 1.8225e-05 - val_root_mean_squared_error: 0.0043
#
# Epoch 00017: val_root_mean_squared_error improved from 0.00441 to 0.00427, saving model to gru-30min-3.h5
# Epoch 18/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.3782e-05 - root_mean_squared_error: 0.0058 - val_loss: 1.7940e-05 - val_root_mean_squared_error: 0.0042
#
# Epoch 00018: val_root_mean_squared_error improved from 0.00427 to 0.00424, saving model to gru-30min-3.h5
# Epoch 19/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.3029e-05 - root_mean_squared_error: 0.0057 - val_loss: 1.7344e-05 - val_root_mean_squared_error: 0.0042
#
# Epoch 00019: val_root_mean_squared_error improved from 0.00424 to 0.00416, saving model to gru-30min-3.h5
# Epoch 20/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.2643e-05 - root_mean_squared_error: 0.0057 - val_loss: 1.7120e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00020: val_root_mean_squared_error improved from 0.00416 to 0.00414, saving model to gru-30min-3.h5
# Epoch 21/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.1758e-05 - root_mean_squared_error: 0.0056 - val_loss: 1.6110e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00021: val_root_mean_squared_error improved from 0.00414 to 0.00401, saving model to gru-30min-3.h5
# Epoch 22/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.1084e-05 - root_mean_squared_error: 0.0056 - val_loss: 1.7981e-05 - val_root_mean_squared_error: 0.0042
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.00401
# Epoch 23/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.0645e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.6125e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.00401
# Epoch 24/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.0674e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.6496e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.00401
# Epoch 25/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.0031e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.4836e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00025: val_root_mean_squared_error improved from 0.00401 to 0.00385, saving model to gru-30min-3.h5
# Epoch 26/50
# ...
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.00352
# Epoch 42/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5181e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.2658e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.00352
# Epoch 43/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.4882e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.2001e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00043: val_root_mean_squared_error improved from 0.00352 to 0.00346, saving model to gru-30min-3.h5
# Epoch 44/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5095e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.3489e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.00346
# Epoch 45/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.5549e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.2622e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.00346
# Epoch 46/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.4852e-05 - root_mean_squared_error: 0.0050 - val_loss: 1.3181e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.00346
# Epoch 47/50
# 50/50 [==============================] - 0s 5ms/step - loss: 2.4002e-05 - root_mean_squared_error: 0.0049 - val_loss: 1.2508e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.00346
# Epoch 48/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.4139e-05 - root_mean_squared_error: 0.0049 - val_loss: 1.3076e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.00346
# Epoch 49/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.3591e-05 - root_mean_squared_error: 0.0049 - val_loss: 1.2275e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.00346
# Epoch 50/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.3474e-05 - root_mean_squared_error: 0.0048 - val_loss: 1.1983e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00050: val_root_mean_squared_error improved from 0.00346 to 0.00346, saving model to gru-30min-3.h5
# Epoch 1/50
# 50/50 [==============================] - 1s 8ms/step - loss: 0.0166 - root_mean_squared_error: 0.1287 - val_loss: 1.2136e-04 - val_root_mean_squared_error: 0.0110
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.01102, saving model to gru-30min-4.h5
# Epoch 2/50
# 50/50 [==============================] - 0s 4ms/step - loss: 1.7932e-04 - root_mean_squared_error: 0.0134 - val_loss: 9.1443e-05 - val_root_mean_squared_error: 0.0096
#
# Epoch 00002: val_root_mean_squared_error improved from 0.01102 to 0.00956, saving model to gru-30min-4.h5
# Epoch 3/50
# 50/50 [==============================] - 0s 4ms/step - loss: 9.7682e-05 - root_mean_squared_error: 0.0099 - val_loss: 5.7873e-05 - val_root_mean_squared_error: 0.0076
#
# Epoch 00003: val_root_mean_squared_error improved from 0.00956 to 0.00761, saving model to gru-30min-4.h5
# Epoch 4/50
# 50/50 [==============================] - 0s 4ms/step - loss: 7.8399e-05 - root_mean_squared_error: 0.0089 - val_loss: 4.3831e-05 - val_root_mean_squared_error: 0.0066
#
# Epoch 00004: val_root_mean_squared_error improved from 0.00761 to 0.00662, saving model to gru-30min-4.h5
# Epoch 5/50
# 50/50 [==============================] - 0s 4ms/step - loss: 6.6987e-05 - root_mean_squared_error: 0.0082 - val_loss: 3.5898e-05 - val_root_mean_squared_error: 0.0060
#
# Epoch 00005: val_root_mean_squared_error improved from 0.00662 to 0.00599, saving model to gru-30min-4.h5
# Epoch 6/50
# 50/50 [==============================] - 0s 4ms/step - loss: 5.9633e-05 - root_mean_squared_error: 0.0077 - val_loss: 3.0178e-05 - val_root_mean_squared_error: 0.0055
#
# Epoch 00006: val_root_mean_squared_error improved from 0.00599 to 0.00549, saving model to gru-30min-4.h5
# Epoch 7/50
# 50/50 [==============================] - 0s 4ms/step - loss: 5.3794e-05 - root_mean_squared_error: 0.0073 - val_loss: 2.7911e-05 - val_root_mean_squared_error: 0.0053
#
# Epoch 00007: val_root_mean_squared_error improved from 0.00549 to 0.00528, saving model to gru-30min-4.h5
# Epoch 8/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.9766e-05 - root_mean_squared_error: 0.0071 - val_loss: 2.4979e-05 - val_root_mean_squared_error: 0.0050
#
# Epoch 00008: val_root_mean_squared_error improved from 0.00528 to 0.00500, saving model to gru-30min-4.h5
# Epoch 9/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.6725e-05 - root_mean_squared_error: 0.0068 - val_loss: 2.3577e-05 - val_root_mean_squared_error: 0.0049
#
# Epoch 00009: val_root_mean_squared_error improved from 0.00500 to 0.00486, saving model to gru-30min-4.h5
# Epoch 10/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.4664e-05 - root_mean_squared_error: 0.0067 - val_loss: 2.1930e-05 - val_root_mean_squared_error: 0.0047
#
# Epoch 00010: val_root_mean_squared_error improved from 0.00486 to 0.00468, saving model to gru-30min-4.h5
# Epoch 11/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.2110e-05 - root_mean_squared_error: 0.0065 - val_loss: 2.1483e-05 - val_root_mean_squared_error: 0.0046
#
# Epoch 00011: val_root_mean_squared_error improved from 0.00468 to 0.00464, saving model to gru-30min-4.h5
# Epoch 12/50
# 50/50 [==============================] - 0s 4ms/step - loss: 4.0857e-05 - root_mean_squared_error: 0.0064 - val_loss: 2.0192e-05 - val_root_mean_squared_error: 0.0045
#
# Epoch 00012: val_root_mean_squared_error improved from 0.00464 to 0.00449, saving model to gru-30min-4.h5
# Epoch 13/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.9235e-05 - root_mean_squared_error: 0.0063 - val_loss: 1.9203e-05 - val_root_mean_squared_error: 0.0044
#
# Epoch 00013: val_root_mean_squared_error improved from 0.00449 to 0.00438, saving model to gru-30min-4.h5
# Epoch 14/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.7836e-05 - root_mean_squared_error: 0.0062 - val_loss: 1.9293e-05 - val_root_mean_squared_error: 0.0044
#
# Epoch 00014: val_root_mean_squared_error did not improve from 0.00438
# Epoch 15/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.7104e-05 - root_mean_squared_error: 0.0061 - val_loss: 1.8487e-05 - val_root_mean_squared_error: 0.0043
#
# Epoch 00015: val_root_mean_squared_error improved from 0.00438 to 0.00430, saving model to gru-30min-4.h5
# Epoch 16/50
# 50/50 [==============================] - 0s 3ms/step - loss: 3.6331e-05 - root_mean_squared_error: 0.0060 - val_loss: 1.8234e-05 - val_root_mean_squared_error: 0.0043
#
# Epoch 00016: val_root_mean_squared_error improved from 0.00430 to 0.00427, saving model to gru-30min-4.h5
# Epoch 17/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.5605e-05 - root_mean_squared_error: 0.0060 - val_loss: 1.7997e-05 - val_root_mean_squared_error: 0.0042
#
# Epoch 00017: val_root_mean_squared_error improved from 0.00427 to 0.00424, saving model to gru-30min-4.h5
# Epoch 18/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.5080e-05 - root_mean_squared_error: 0.0059 - val_loss: 1.7058e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00018: val_root_mean_squared_error improved from 0.00424 to 0.00413, saving model to gru-30min-4.h5
# Epoch 19/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.4997e-05 - root_mean_squared_error: 0.0059 - val_loss: 1.6607e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00019: val_root_mean_squared_error improved from 0.00413 to 0.00408, saving model to gru-30min-4.h5
# Epoch 20/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.3616e-05 - root_mean_squared_error: 0.0058 - val_loss: 1.6591e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00020: val_root_mean_squared_error improved from 0.00408 to 0.00407, saving model to gru-30min-4.h5
# Epoch 21/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.2809e-05 - root_mean_squared_error: 0.0057 - val_loss: 1.7095e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.00407
# Epoch 22/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.2665e-05 - root_mean_squared_error: 0.0057 - val_loss: 1.7144e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.00407
# Epoch 23/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.2017e-05 - root_mean_squared_error: 0.0057 - val_loss: 1.6171e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00023: val_root_mean_squared_error improved from 0.00407 to 0.00402, saving model to gru-30min-4.h5
# Epoch 24/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.1484e-05 - root_mean_squared_error: 0.0056 - val_loss: 1.5727e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00024: val_root_mean_squared_error improved from 0.00402 to 0.00397, saving model to gru-30min-4.h5
# Epoch 25/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.1460e-05 - root_mean_squared_error: 0.0056 - val_loss: 1.5286e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00025: val_root_mean_squared_error improved from 0.00397 to 0.00391, saving model to gru-30min-4.h5
# Epoch 26/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.1333e-05 - root_mean_squared_error: 0.0056 - val_loss: 1.4824e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00026: val_root_mean_squared_error improved from 0.00391 to 0.00385, saving model to gru-30min-4.h5
# Epoch 27/50
# 50/50 [==============================] - 0s 4ms/step - loss: 3.0300e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.6275e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00027: val_root_mean_squared_error did not improve from 0.00385
# Epoch 28/50
# 50/50 [==============================] - 0s 3ms/step - loss: 3.0545e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.5239e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00028: val_root_mean_squared_error did not improve from 0.00385
# Epoch 29/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.9974e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.4826e-05 - val_root_mean_squared_error: 0.0039
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.00385
# Epoch 30/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.9433e-05 - root_mean_squared_error: 0.0054 - val_loss: 1.4189e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00030: val_root_mean_squared_error improved from 0.00385 to 0.00377, saving model to gru-30min-4.h5
# Epoch 31/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.9768e-05 - root_mean_squared_error: 0.0055 - val_loss: 1.4433e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.00377
# Epoch 32/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8937e-05 - root_mean_squared_error: 0.0054 - val_loss: 1.7455e-05 - val_root_mean_squared_error: 0.0042
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.00377
# Epoch 33/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8594e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.4320e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.00377
# Epoch 34/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8815e-05 - root_mean_squared_error: 0.0054 - val_loss: 1.4261e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.00377
# Epoch 35/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.9126e-05 - root_mean_squared_error: 0.0054 - val_loss: 1.3900e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00035: val_root_mean_squared_error improved from 0.00377 to 0.00373, saving model to gru-30min-4.h5
# Epoch 36/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8250e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.6392e-05 - val_root_mean_squared_error: 0.0040
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.00373
# Epoch 37/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8474e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.3275e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00037: val_root_mean_squared_error improved from 0.00373 to 0.00364, saving model to gru-30min-4.h5
# Epoch 38/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7612e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.3034e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00038: val_root_mean_squared_error improved from 0.00364 to 0.00361, saving model to gru-30min-4.h5
# Epoch 39/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8279e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.4636e-05 - val_root_mean_squared_error: 0.0038
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.00361
# Epoch 40/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7664e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.3128e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00040: val_root_mean_squared_error did not improve from 0.00361
# Epoch 41/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7073e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.3799e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.00361
# Epoch 42/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7264e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.3375e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.00361
# Epoch 43/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8360e-05 - root_mean_squared_error: 0.0053 - val_loss: 1.2817e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00043: val_root_mean_squared_error improved from 0.00361 to 0.00358, saving model to gru-30min-4.h5
# Epoch 44/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6838e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.2652e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00044: val_root_mean_squared_error improved from 0.00358 to 0.00356, saving model to gru-30min-4.h5
# Epoch 45/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7076e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.2443e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00045: val_root_mean_squared_error improved from 0.00356 to 0.00353, saving model to gru-30min-4.h5
# Epoch 46/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6459e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.6771e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.00353
# Epoch 47/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.7142e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.3719e-05 - val_root_mean_squared_error: 0.0037
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.00353
# Epoch 48/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.8935e-05 - root_mean_squared_error: 0.0054 - val_loss: 1.6579e-05 - val_root_mean_squared_error: 0.0041
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.00353
# Epoch 49/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6689e-05 - root_mean_squared_error: 0.0052 - val_loss: 1.2704e-05 - val_root_mean_squared_error: 0.0036
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.00353
# Epoch 50/50
# 50/50 [==============================] - 0s 4ms/step - loss: 2.6029e-05 - root_mean_squared_error: 0.0051 - val_loss: 1.2000e-05 - val_root_mean_squared_error: 0.0035
#
# Epoch 00050: val_root_mean_squared_error improved from 0.00353 to 0.00346, saving model to gru-30min-4.h5

# %%
models = []
for i in range(5):
    # models.append(tf.keras.models.load_model('../Trained_Models/gru'+str(i)+'.h5'))
    models.append(tf.keras.models.load_model('gru-30min-'+str(i)+'.h5'))

# %%
predictions = []
for model in models:
    predictions.append(model.predict(X_test))

# %%
# prediction = model.predict(X_test)
for i, prediction in enumerate(predictions):
    mse = mean_squared_error(y_test, prediction)
    rmse = mean_squared_error(y_test, prediction, squared=False)
    mae = mean_absolute_error(y_test, prediction)

    metrics = '\n'.join((
        '$MSE=%f$' % (mse),
        '$RMSE=%f$' % (rmse),
        '$MAE=%f$' % (mae)
    ))

    plt.figure(figsize=(26, 10))
    plt.plot(prediction, label='Prediction Price')
    plt.plot(y_test, label='Ground Truth')
    plt.legend()
    plt.title('Sub-model ' + str(i+1) + ': Predictions for next 30 min')

    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    plt.text(0.1, 0.2, metrics, fontsize=14,
            verticalalignment='top', bbox=props)

    # plt.savefig('no_senti.png', dpi=500)
    plt.show()

# %%
prediction = np.mean(np.array(predictions), axis=0)
mse = mean_squared_error(y_test, prediction)
rmse = mean_squared_error(y_test, prediction, squared=False)
mae = mean_absolute_error(y_test, prediction)

metrics = '\n'.join((
    '$MSE=%f$' % (mse),
    '$RMSE=%f$' % (rmse),
    '$MAE=%f$' % (mae)
))

plt.figure(figsize=(26, 10))
plt.plot(prediction, label='Prediction Price')
plt.plot(y_test, label='Ground Truth')
plt.legend()
plt.title('Predictions for next 30 min')

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
plt.text(0.1, 0.2, metrics, fontsize=14,
        verticalalignment='top', bbox=props)

# plt.savefig('no_senti.png', dpi=500)
plt.show()

# %%
pred_prices = scaler_label.inverse_transform(prediction)
true_prices = scaler_label.inverse_transform(y_test.reshape(-1,1))

mse = mean_squared_error(true_prices, pred_prices)
rmse = mean_squared_error(true_prices, pred_prices, squared=False)
mae = mean_absolute_error(true_prices, pred_prices)

metrics = '\n'.join((
    '$MSE=%f$' % (mse),
    '$RMSE=%f$' % (rmse),
    '$MAE=%f$' % (mae)
))

plt.figure(figsize=(26, 10))
plt.plot(pred_prices, label='Prediction Price')
plt.plot(true_prices, label='Ground Truth')
plt.legend()
plt.title('(GRU) Predictions for next 30 min')

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
plt.text(0, 40000, metrics, fontsize=14,
        verticalalignment='top', bbox=props)

# plt.savefig('no_senti.png', dpi=500)
plt.show()
